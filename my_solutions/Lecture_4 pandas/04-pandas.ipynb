# %% [markdown]
# # Pandas - Data Analysis with Python
#
#
# Pandas is a high-performance, easy-to-use data structures and data analysis tools.
#
# <img src="figs/pandas.jpg" style="width: 500px;"/>

# %% [markdown]
# # Pandas
# Pandas are fascinating creatures known for their distinctive black and white fur coat. Native to certain parts of China, these gentle giants primarily feed on bamboo, which makes up about 99% of their diet. Although known for their calm demeanor, they are adept tree climbers and swimmers. Pandas play a crucial role in the bamboo forests where they roam by facilitating seed dispersal, thus helping in the growth and proliferation of bamboo. Moreover, they are a symbol of peace and harmony in Chinese culture, and efforts are continuously being made to conserve their habitats and increase their population, which is threatened due to habitat loss and other environmental factors.

# %% [markdown]
# ## What is it good for?
#
# Working with (large) data sets and created automated data processes.
#
# Pandas is extensively used to prepare data in data science (machine learning, data analytics, ...)
#
# **Examples**:
# * **Import and export** data into standard formats (CSV, Excel, Latex, ..).
# * Combine with Numpy for **advanced computations** or Matplotlib for **visualisations**.
# * Calculate **statistics** and answer questions about the data, like
#   * What's the average, median, max, or min of each column?
#   * Does column A correlate with column B?
#   * What does the distribution of data in column C look like?
# * **Clean** up data (e.g. fill out missing information and fix inconsistent formatting) and **merge** multiple data sets into one common dataset.

# %% [markdown]
# ## Some interesting data sources
#
# ### (Norsk) Statistisk sentralbyrå
# https://www.ssb.no
#
# Employment rates, immigration rates housing market, ...
#
# <img src="figs/ssb.png" style="width: 400px;"/>

# %% [markdown]
# ### Finn API
# https://www.finn.no/api
#
# Note: Unfortunately currently only open for business

# %% [markdown]
# ### Oslo Bysykkel API
#
# https://oslobysykkel.no/en/open-data
#
# Live usage data and statistics.
#
# **!! This lecture will use this data.**

# %% [markdown]
# ### Ruter API
# https://developer.entur.org
#
# Travel planning and live departure information. For example live departure information
#
#
# <img src="figs/raspberry_pi_project.jpg" style="width: 300px;"/>
#
# (Credits: Malte Pliszewski)

# %% [markdown]
# ### YR data
# http://om.yr.no/verdata/free-weather-data/
#
# ### Financial and economic data
# https://www.quandl.com/
#
# ### And lots lots more:
#
# * Almost every "smart" device, internet of things, ...
# * https://github.com/public-apis/public-apis
# * Web scraping

# %% [markdown]
# ## More information
#
# * Official Pandas documentation: http://pandas.pydata.org/pandas-docs/stable/tutorials.html
# * Pandas cookbook: http://pandas.pydata.org/pandas-docs/stable/cookbook.html
# * Wes McKinney, Python for Data Analysis
# ![Python for Data Analysis](figs/python_for_data_analysis.gif "Python for Data Analysis")

# %% [markdown]
# ## Installation
#
# * If you have Anaconda: Already installed
# * If you have Miniconda:
#       conda install pandas
# * If you have your another Python distribution:
#       python3 -m pip install pandas

# %% [markdown]
# ## Quick guide through Pandas

# %%
# %matplotlib inline

# %% [markdown]
# First import pandas (and numpy) as usual.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## The basic data structures of Pandas
#
# <center>
# <img src="https://storage.googleapis.com/lds-media/images/series-and-dataframe.width-1200.png
# " style="width: 500px;"/>
#
#     Figure: Fundamental data types in Pandas.
#     (Image source: https://www.learndatasci.com)
# </center>

# %% [markdown]
# ### Series
#
# Series in Pands are 1-dimensional, axis-labeled array capable of holding any data type.
#
# The simplest way to create a Series is from a list:

# %%
s1 = pd.Series([1, 3, 5, np.nan, 6, 8])
s1
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %% [markdown]
# * Pandas relies on numpy to store the underlying data. Note the dtype property that we already know from numpy.
# * If no dtype is specified, it chooses a stuitable dtype for your data.

# %% [markdown]
# ## Specifying the axis label
#
# By default, the data is labeld by integers. This can be changed with:

# %%
s2 = pd.Series([1, 3, 5, np.nan, 6, 8], index=["a", "b", "c", "d", "e", "f"])
s2.plot(label ="blue line").legend()

# %% [markdown]
# # Time-series data
#
# A common use-case is to have data labeled with time stamps (for instance price, currency and weather data).

# %%
dates = pd.date_range(start='20181023', end='20191023', periods=6)
dates
# Out:
# DatetimeIndex(['2018-10-23', '2019-01-04', '2019-03-18', '2019-05-30',
#                '2019-08-11', '2019-10-23'],
#               dtype='datetime64[ns]', freq=None)

# %%
s3 = pd.Series([1, 3, 5, np.nan, 6, 8], index=dates)
s3
# Out:
# 2018-10-23    1.0
# 2019-01-04    3.0
# 2019-03-18    5.0
# 2019-05-30    NaN
# 2019-08-11    6.0
# 2019-10-23    8.0
# dtype: float64

# %%
s3.plot()
# Out:
# <Axes: >

# %% [markdown]
# # DataFrame
#
# DataFrame's are 2-dimensional labeled data structure with columns of potentially different types.
#
# The most basic method to create a DataFrame is from a dictionary:

# %%
data = {
    'apples': [3, 0, 0, 1],
    'pears':  [6, 1, 3, 5]
}

purchases = pd.DataFrame(data)
purchases
# Out:
#    apples  pears
# 0       3      6
# 1       0      1
# 2       0      3
# 3       1      5

# %% [markdown]
# **How did this work:** Each (key, value) pair in the dictionary is interpreted as a column in the data table. The key is used as column label.
#
# As with Series, we can provide an index to label the y-axis:

# %%
data = {
    'apples': [3, 0, 0, 1],
    'pears':  [6, 1, 3, 2]
}
customers = ["Marie", "Jør®®gen", "Hilde", "Hans"]

purchases = pd.DataFrame(data, index=customers)
purchases
# Out:
#           apples  pears
# Marie          3      6
# Jør®®gen       0      1
# Hilde          0      3
# Hans           1      2

# %% [markdown]
# ## Extracting columns from a DataTable
#
# When **loc**ating (i.e. extracting) a column or row of a DataFrame, one obtains a `Series`

# %%
purchases.loc["Hans"]
# Out:
# apples    1
# pears     2
# Name: Hans, dtype: int64

# %%
purchases["apples"]
# Out:
# Marie       3
# Jør®®gen    0
# Hilde       0
# Hans        1
# Name: apples, dtype: int64

# %%
type(purchases.loc["Hans"])
# Out:
# pandas.core.series.Series

# %% [markdown]
# ## Combining two Series to a DataFrame

# %%
s1 = pd.Series([1, 2], index=['A', 'B'])
s2 = pd.Series([3, 4], index=['A', 'B'])

print(s1)
print(s2)

A = pd.concat([s1, s2, s1], axis=1, sort=False)
A
# Out:
# A    1
# B    2
# dtype: int64
# A    3
# B    4
# dtype: int64
#    0  1  2
# A  1  3  1
# B  2  4  2

# %% [markdown]
# ## Loading data from file
#
# For pratical applications, we will read the data from a file rather from a dictionary.
#
# Pandas offers various drivers to load data in different formats:

# %%
pd.read_*?
# Out:
# C:\Users\pvwol\AppData\Roaming\Python\Python311\site-packages\IPython\utils\wildcard.py:70: FutureWarning: pandas.Float64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   ns[key] = getattr(obj, key)
# C:\Users\pvwol\AppData\Roaming\Python\Python311\site-packages\IPython\utils\wildcard.py:70: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   ns[key] = getattr(obj, key)
# C:\Users\pvwol\AppData\Roaming\Python\Python311\site-packages\IPython\utils\wildcard.py:70: FutureWarning: pandas.UInt64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   ns[key] = getattr(obj, key)
# pd.read_clipboard
# pd.read_csv
# pd.read_excel
# pd.read_feather
# pd.read_fwf
# pd.read_gbq
# pd.read_hdf
# pd.read_html
# pd.read_json
# pd.read_orc
# pd.read_parquet
# pd.read_pickle
# pd.read_sas
# pd.read_spss
# pd.read_sql
# pd.read_sql_query
# pd.read_sql_table
# pd.read_stata
# pd.read_table
# pd.read_xml

# %% [markdown]
# We will see this in a real application in a moment.

# %% [markdown]
# # Data analysis on the Oslo Byskkel data
#
#
#
# <img src="https://cdn.sanity.io/images/23ukf9xm/production/4acf4a351c2174972b61465210f56878c41bad65-5698x3799.jpg?w=1200&h=600&fit=max" style="width: 500px;"/>

# %% [markdown]
# **Goal**: Perfrom data analysis of the bike usage, such as:
# * Identify peak and low points of bike station usage (over a year, week or day)?
# * Which are the most and least used bike stations?
# * Which are the most and least used bike routes?
# * Visualize the bike usage in Oslo.

# %% [markdown]
# ## Step 1: Data aquisition and inspection
#
# The monthly usage data can be downloaded here: https://oslobysykkel.no/en/open-data

# %% [markdown]
# I downloaded the data from August to September 2016:

# %%
# !dir data\bysykkel
# Out:
#  Volume in drive C is Windows-SSD
#  Volume Serial Number is C673-F62B
#
#  Directory of c:\Users\pvwol\BI\Autumn 25\Courses\Big Data Curation\Lecture_4 pandas\data\bysykkel
#
# 12/09/2025  12:32    <DIR>          .
# 12/09/2025  12:32    <DIR>          ..
# 12/09/2025  12:32        36,526,785 08.csv
# 12/09/2025  12:32               102 get_station_data.sh
# 12/09/2025  12:32            64,322 stations.json
# 12/09/2025  12:32        14,565,493 trips-2016.10.1-2016.10.31.csv
# 12/09/2025  12:32        22,660,582 trips-2016.9.1-2016.9.30.csv
# 12/09/2025  12:32        38,884,105 trips-2021.10.1-2021.10.31.csv
# 12/09/2025  12:32        38,160,996 trips-2021.9.1-2021.9.30.csv
#                7 File(s)    150,862,385 bytes
#                2 Dir(s)  306,132,078,592 bytes free

# %% [markdown]
# Let's inspect the content of one of these files:

# %% [markdown]
# ## Loading the data into a DataFrame
#
# Since this is a comma seperated file, we can use Panda's `read_csv` function:

# %%
import pandas as pd
trips = pd.read_csv('data/bysykkel/trips-2016.10.1-2016.10.31.csv', 
                    sep=',')

# %% [markdown]
# The result is stored in  a `DataFrame` object. The first row of the csv was used as column labels.

# %%
trips.head()
# Out:
#    Start station                 Start time  End station  \
# 0            283  2016-10-01 06:00:08 +0200        238.0
# 1            169  2016-10-01 06:00:41 +0200        175.0
# 2            211  2016-10-01 06:01:02 +0200        162.0
# 3            200  2016-10-01 06:01:20 +0200        163.0
# 4            157  2016-10-01 06:02:16 +0200        163.0
#
#                     End time
# 0  2016-10-01 06:09:47 +0200
# 1  2016-10-01 06:11:07 +0200
# 2  2016-10-01 06:15:52 +0200
# 3  2016-10-01 06:15:04 +0200
# 4  2016-10-01 06:04:29 +0200

# %% [markdown]
# We can use the `head` and `tail` functions to only show the (by default 5) top rows in the data table.

# %%
trips.head(5)
# Out:
#    Start station                 Start time  End station  \
# 0            283  2016-10-01 06:00:08 +0200        238.0
# 1            169  2016-10-01 06:00:41 +0200        175.0
# 2            211  2016-10-01 06:01:02 +0200        162.0
# 3            200  2016-10-01 06:01:20 +0200        163.0
# 4            157  2016-10-01 06:02:16 +0200        163.0
#
#                     End time
# 0  2016-10-01 06:09:47 +0200
# 1  2016-10-01 06:11:07 +0200
# 2  2016-10-01 06:15:52 +0200
# 3  2016-10-01 06:15:04 +0200
# 4  2016-10-01 06:04:29 +0200

# %% [markdown]
# ## Fixing columns types
#
# Pandas tries to **automatically detect the type** of a column:

# %%
trips.dtypes
# Out:
# Start station      int64
# Start time        object
# End station      float64
# End time          object
# dtype: object

# %% [markdown]
# We can see that this **automatic detection failed** for:
#
# * `Start time`:  should be a date
# * `End time`:  should be a date
# * `End station`:  should be a integer

# %% [markdown]
# ## Fixing  start and end times

# %% [markdown]
# In order to be able to sort or filter by date, we need to tell Pandas that this column should be parsed as dates. We can do this directly when loading in the data:

# %%
trips = trips_oct = pd.read_csv(
    "data/bysykkel/trips-2016.10.1-2016.10.31.csv",
    sep=",",
    parse_dates=["Start time", "End time"],
    date_parser=lambda col: pd.to_datetime(col, utc=True),
)

# %% [markdown]
# **Note!**  The lambda function is necessary to read dates with mixed time-zones!

# %%
trips.dtypes
# Out:
# Start station                  int64
# Start time       datetime64[ns, UTC]
# End station                  float64
# End time         datetime64[ns, UTC]
# dtype: object

# %%
trips.head()
# Out:
#    Start station                Start time  End station  \
# 0            283 2016-10-01 04:00:08+00:00        238.0
# 1            169 2016-10-01 04:00:41+00:00        175.0
# 2            211 2016-10-01 04:01:02+00:00        162.0
# 3            200 2016-10-01 04:01:20+00:00        163.0
# 4            157 2016-10-01 04:02:16+00:00        163.0
#
#                    End time
# 0 2016-10-01 04:09:47+00:00
# 1 2016-10-01 04:11:07+00:00
# 2 2016-10-01 04:15:52+00:00
# 3 2016-10-01 04:15:04+00:00
# 4 2016-10-01 04:04:29+00:00

# %% [markdown]
# ### Fixing end station

# %% [markdown]
# We expected `End station` to be of type `np.int64`. We can enforce this with:

# %%
import numpy as np
trips = pd.read_csv(
    "data/bysykkel/trips-2016.10.1-2016.10.31.csv",
    sep=",",
    parse_dates=["Start time", "End time"],
    date_parser=lambda col: pd.to_datetime(col, utc=True),
    dtype={"End station": np.int64},
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[27], line 2
#       1 import numpy as np
# ----> 2 trips = pd.read_csv(
#       3     "data/bysykkel/trips-2016.10.1-2016.10.31.csv",
#       4     sep=",",
#       5     parse_dates=["Start time", "End time"],
#       6     date_parser=lambda col: pd.to_datetime(col, utc=True),
#       7     dtype={"End station": np.int64},
#       8 )
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\io\parsers\readers.py:950, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     946     defaults={"delimiter": ","},
#     947 )
#     948 kwds.update(kwds_defaults)
# --> 950 return _read(filepath_or_buffer, kwds)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\io\parsers\readers.py:611, in _read(filepath_or_buffer, kwds)
#     608     return parser
#     610 with parser:
# --> 611     return parser.read(nrows)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\io\parsers\readers.py:1778, in TextFileReader.read(self, nrows)
#    1771 nrows = validate_integer("nrows", nrows)
#    1772 try:
#    1773     # error: "ParserBase" has no attribute "read"
#    1774     (
#    1775         index,
#    1776         columns,
#    1777         col_dict,
# -> 1778     ) = self._engine.read(  # type: ignore[attr-defined]
#    1779         nrows
#    1780     )
#    1781 except Exception:
#    1782     self.close()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\io\parsers\c_parser_wrapper.py:230, in CParserWrapper.read(self, nrows)
#     228 try:
#     229     if self.low_memory:
# --> 230         chunks = self._reader.read_low_memory(nrows)
#     231         # destructive to chunks
#     232         data = _concatenate_chunks(chunks)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\_libs\parsers.pyx:808, in pandas._libs.parsers.TextReader.read_low_memory()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\_libs\parsers.pyx:890, in pandas._libs.parsers.TextReader._read_rows()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\_libs\parsers.pyx:1037, in pandas._libs.parsers.TextReader._convert_column_data()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\_libs\parsers.pyx:1068, in pandas._libs.parsers.TextReader._convert_tokens()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\_libs\parsers.pyx:1187, in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# ValueError: Integer column has NA values in column 2

# %% [markdown]
# **Conclusion**:
# `End station` contains `Not a Number` values or`NaN` values, which can be represented in the `float` datatype, but not in the `int` datatype

# %%
trips.sort_values("End station").tail(100)
# Out:
#         Start station                Start time  End station  \
# 174509            182 2016-10-21 12:53:05+00:00        309.0
# 211908            215 2016-10-27 09:18:41+00:00        309.0
# 111557            162 2016-10-13 10:31:14+00:00        309.0
# 105880            162 2016-10-12 16:08:20+00:00        309.0
# 234911            267 2016-10-30 14:44:27+00:00        309.0
# ...               ...                       ...          ...
# 107496            233 2016-10-12 19:05:32+00:00          NaN
# 117359            267 2016-10-13 20:55:38+00:00          NaN
# 153782            232 2016-10-19 06:08:40+00:00          NaN
# 200309            158 2016-10-25 17:22:32+00:00          NaN
# 235053            192 2016-10-30 15:01:47+00:00          NaN
#
#                         End time
# 174509 2016-10-21 13:50:30+00:00
# 211908 2016-10-27 09:32:19+00:00
# 111557 2016-10-13 10:38:54+00:00
# 105880 2016-10-12 16:20:24+00:00
# 234911 2016-10-30 14:59:58+00:00
# ...                          ...
# 107496 2016-10-17 05:56:12+00:00
# 117359 2016-10-14 09:43:21+00:00
# 153782 2016-10-20 05:42:02+00:00
# 200309 2016-10-25 18:02:16+00:00
# 235053 2016-10-31 10:40:41+00:00
#
# [100 rows x 4 columns]

# %% [markdown]
# But we *can* do this if we discard the rows with missing data. Pandas has various utilities for dealing with missing data

# %%
s = pd.Series([1,2,np.nan, 4,5, np.nan])
s.dropna()
# Out:
# 0    1.0
# 1    2.0
# 3    4.0
# 4    5.0
# dtype: float64

# %%
trips = trips.dropna(subset=["End station"]).astype({"End station": int})
trips.tail(5)
# Out:
#         Start station                Start time  End station  \
# 242753            284 2016-10-31 22:53:30+00:00          164
# 242754            218 2016-10-31 22:53:48+00:00          292
# 242755            204 2016-10-31 22:54:28+00:00          277
# 242756            204 2016-10-31 22:56:57+00:00          201
# 242757            268 2016-10-31 22:59:10+00:00          299
#
#                         End time
# 242753 2016-10-31 23:04:13+00:00
# 242754 2016-10-31 23:09:17+00:00
# 242755 2016-10-31 23:01:59+00:00
# 242756 2016-10-31 23:02:16+00:00
# 242757 2016-10-31 23:04:55+00:00

# %%
trips.astype({'End station': 'int64'}).dtypes
# Out:
# Start station                  int64
# Start time       datetime64[ns, UTC]
# End station                    int64
# End time         datetime64[ns, UTC]
# dtype: object

# %% [markdown]
# # Selecting data from dataframes

# %% [markdown]
# ## Selecting columns

# %% [markdown]
# There are three main ways to select columns from a DataTable:
#
# * indexing notation [].
# * The .loc accessor
# * The .iloc accessor

# %% [markdown]
# ## Selecting columns with the index notation

# %% [markdown]
# Use the index notation if you know the name of the column(s) that you want to extract.
#
# If you use a single column, the result is a Series:

# %%
trips["Start time"].head()
# Out:
# 0   2016-10-01 04:00:08+00:00
# 1   2016-10-01 04:00:41+00:00
# 2   2016-10-01 04:01:02+00:00
# 3   2016-10-01 04:01:20+00:00
# 4   2016-10-01 04:02:16+00:00
# Name: Start time, dtype: datetime64[ns, UTC]

# %% [markdown]
# ## Selecting multiple columns
#
# Multiple columns are selected by indexing with a list of column titles. The result is a DataFrame:

# %%
trips[["Start time", "End time"]].head()
# Out:
#                  Start time                  End time
# 0 2016-10-01 04:00:08+00:00 2016-10-01 04:09:47+00:00
# 1 2016-10-01 04:00:41+00:00 2016-10-01 04:11:07+00:00
# 2 2016-10-01 04:01:02+00:00 2016-10-01 04:15:52+00:00
# 3 2016-10-01 04:01:20+00:00 2016-10-01 04:15:04+00:00
# 4 2016-10-01 04:02:16+00:00 2016-10-01 04:04:29+00:00

# %% [markdown]
# ### Selecting rows and columns
#
# `loc`  a more explicit alternative for selecting rows and/or columns

# %% [markdown]
# **Syntax**: `DataFrame.loc[ROWS, COLUMNS]`

# %%
trips.loc[[1,5], ["Start time", "End time"]]
# Out:
#                  Start time                  End time
# 1 2016-10-01 04:00:41+00:00 2016-10-01 04:11:07+00:00
# 5 2016-10-01 04:04:22+00:00 2016-10-01 04:24:40+00:00

# %% [markdown]
# Use the : notation to select ranges of columns/rows.

# %% [markdown]
# ### Selecting rows and columns based on indices
#
# `iloc` is the same is `loc` but expectes the index positions instead of column names (i.e. always uses intergers)

# %% [markdown]
# **Syntax**: `DataFrame.iloc[ROWS, COLUMNS]`

# %%
trips.iloc[:5, 0:2]
# Out:
#    Start station                Start time
# 0            283 2016-10-01 04:00:08+00:00
# 1            169 2016-10-01 04:00:41+00:00
# 2            211 2016-10-01 04:01:02+00:00
# 3            200 2016-10-01 04:01:20+00:00
# 4            157 2016-10-01 04:02:16+00:00

# %% [markdown]
# ## Selecting based on values in columns
#
# Comparisons on a series produce a new series of booleans.
# This can be used to construct a "mask" of values that can be passed
# to loc or index-access:

# %%
trips["Start station"] == 283
# Out:
# 0          True
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 242753    False
# 242754    False
# 242755    False
# 242756    False
# 242757    False
# Name: Start station, Length: 242747, dtype: bool

# %% [markdown]
# We can use this information to determine the number of trips that started at station 283:

# %%
(trips["Start station"] == 283).sum()
# Out:
# np.int64(1321)

# %% [markdown]
# And inspect details about those trips:

# %%
trips[trips["Start station"] == 283]
# Out:
#         Start station                Start time  End station  \
# 0                 283 2016-10-01 04:00:08+00:00          238
# 359               283 2016-10-01 06:55:45+00:00          219
# 486               283 2016-10-01 07:24:19+00:00          284
# 572               283 2016-10-01 07:38:59+00:00          170
# 650               283 2016-10-01 07:49:42+00:00          189
# ...               ...                       ...          ...
# 242126            283 2016-10-31 18:43:21+00:00          267
# 242140            283 2016-10-31 18:48:02+00:00          176
# 242313            283 2016-10-31 19:46:46+00:00          222
# 242357            283 2016-10-31 20:01:14+00:00          184
# 242502            283 2016-10-31 21:00:13+00:00          284
#
#                         End time
# 0      2016-10-01 04:09:47+00:00
# 359    2016-10-01 07:01:49+00:00
# 486    2016-10-01 07:28:29+00:00
# 572    2016-10-01 07:41:09+00:00
# 650    2016-10-01 07:53:22+00:00
# ...                          ...
# 242126 2016-10-31 18:46:47+00:00
# 242140 2016-10-31 18:52:59+00:00
# 242313 2016-10-31 19:59:02+00:00
# 242357 2016-10-31 20:05:26+00:00
# 242502 2016-10-31 21:05:17+00:00
#
# [1321 rows x 4 columns]

# %% [markdown]
# We can even do complex arithmetic on columns

# %%
durations = trips["End time"] - trips["Start time"]
durations
# Out:
# 0        0 days 00:09:39
# 1        0 days 00:10:26
# 2        0 days 00:14:50
# 3        0 days 00:13:44
# 4        0 days 00:02:13
#                ...
# 242753   0 days 00:10:43
# 242754   0 days 00:15:29
# 242755   0 days 00:07:31
# 242756   0 days 00:05:19
# 242757   0 days 00:05:45
# Length: 242747, dtype: timedelta64[ns]

# %%
durations.quantile(0.9)
# Out:
# Timedelta('0 days 00:23:20')

# %% [markdown]
# Anything that results in a boolean Series with the same index as a dataframe or series
# can be used to select a subset of data.
#
# This example says: give us the top 10% (above 90th percential) of trips by duration

# %%
trips[durations >= durations.quantile(0.9)]
# Out:
#         Start station                Start time  End station  \
# 33                285 2016-10-01 04:33:13+00:00          222
# 41                277 2016-10-01 04:37:56+00:00          277
# 52                183 2016-10-01 04:44:03+00:00          272
# 64                208 2016-10-01 04:52:09+00:00          281
# 109               251 2016-10-01 05:16:10+00:00          185
# ...               ...                       ...          ...
# 242610            158 2016-10-31 21:42:49+00:00          158
# 242632            257 2016-10-31 21:51:15+00:00          169
# 242722            191 2016-10-31 22:31:43+00:00          253
# 242744            189 2016-10-31 22:46:57+00:00          275
# 242752            211 2016-10-31 22:52:24+00:00          281
#
#                         End time
# 33     2016-10-01 05:57:49+00:00
# 41     2016-10-01 05:30:49+00:00
# 52     2016-10-01 05:08:39+00:00
# 64     2016-10-01 14:08:30+00:00
# 109    2016-10-01 09:54:50+00:00
# ...                          ...
# 242610 2016-10-31 22:38:37+00:00
# 242632 2016-10-31 23:29:49+00:00
# 242722 2016-11-01 01:56:19+00:00
# 242744 2016-11-01 00:45:11+00:00
# 242752 2016-11-01 00:17:32+00:00
#
# [24288 rows x 4 columns]

# %% [markdown]
# Or specify a value. Pandas has lots of *very* useful convenience functions
# for comparing dates. You can often specify a string which pandas will interpret

# %%
trips[durations >= "1 day"]
# Out:
#         Start station                Start time  End station  \
# 178               243 2016-10-01 05:43:24+00:00          175
# 963               226 2016-10-01 08:39:35+00:00          172
# 1370              226 2016-10-01 09:35:22+00:00          173
# 3629              199 2016-10-01 12:43:13+00:00          240
# 4677              301 2016-10-01 13:59:43+00:00          176
# ...               ...                       ...          ...
# 229348            204 2016-10-29 13:25:04+00:00          182
# 229826            260 2016-10-29 14:13:46+00:00          219
# 230667            267 2016-10-29 15:52:05+00:00          277
# 232648            229 2016-10-30 06:38:10+00:00          287
# 233168            237 2016-10-30 10:25:03+00:00          264
#
#                         End time
# 178    2016-10-18 07:53:19+00:00
# 963    2016-10-06 17:09:17+00:00
# 1370   2016-10-17 05:48:48+00:00
# 3629   2016-10-03 21:08:30+00:00
# 4677   2016-10-04 05:36:49+00:00
# ...                          ...
# 229348 2016-10-31 07:37:25+00:00
# 229826 2016-10-31 05:41:37+00:00
# 230667 2016-10-30 18:40:50+00:00
# 232648 2016-10-31 08:05:02+00:00
# 233168 2016-10-31 19:06:35+00:00
#
# [291 rows x 4 columns]

# %% [markdown]
# ## Special handling of strings and datetime
#
# Series with datetime data or strings have special accessor methods for working with that kind of data
# by accessing a `.dt` or `.str` attribute, giving access to

# %%
trips["Start time"].dt.weekday
# Out:
# 0         5
# 1         5
# 2         5
# 3         5
# 4         5
#          ..
# 242753    0
# 242754    0
# 242755    0
# 242756    0
# 242757    0
# Name: Start time, Length: 242747, dtype: int32

# %% [markdown]
# Boolean series can be combined using Python's bitwise or (`|`) and bitwise and (`&`) operators.
# So we can find late-night trips, i.e. those that start between 22:00 and 04:00

# %%
trips[(trips["Start time"].dt.hour >= 22) | (trips["Start time"].dt.hour <= 3)]
# Out:
#         Start station                Start time  End station  \
# 26424             287 2016-10-04 03:59:55+00:00          195
# 26425             229 2016-10-04 03:59:56+00:00          247
# 79522             206 2016-10-10 03:59:56+00:00          196
# 108408            283 2016-10-13 03:59:52+00:00          280
# 108409            251 2016-10-13 03:59:54+00:00          265
# ...               ...                       ...          ...
# 242753            284 2016-10-31 22:53:30+00:00          164
# 242754            218 2016-10-31 22:53:48+00:00          292
# 242755            204 2016-10-31 22:54:28+00:00          277
# 242756            204 2016-10-31 22:56:57+00:00          201
# 242757            268 2016-10-31 22:59:10+00:00          299
#
#                         End time
# 26424  2016-10-04 04:03:18+00:00
# 26425  2016-10-04 04:05:28+00:00
# 79522  2016-10-10 04:04:46+00:00
# 108408 2016-10-13 04:05:36+00:00
# 108409 2016-10-13 04:05:13+00:00
# ...                          ...
# 242753 2016-10-31 23:04:13+00:00
# 242754 2016-10-31 23:09:17+00:00
# 242755 2016-10-31 23:01:59+00:00
# 242756 2016-10-31 23:02:16+00:00
# 242757 2016-10-31 23:04:55+00:00
#
# [235 rows x 4 columns]

# %% [markdown]
# ## GroupBy
#
# grouping is like creating a dictionary of dataframes for subsets of your data.
# You can group by any kind of value.
# The result is like a dictionary of data frames,
# where each one contains a subset of data matching some criterion.

# %% [markdown]
# You can pass groupby one or more column names to group by unique values on that column

# %%
trips.groupby("Start station").count()
# Out:
#                Start time  End station  End time
# Start station
# 157                  2108         2108      2108
# 158                  1465         1465      1465
# 159                  1597         1597      1597
# 160                  1121         1121      1121
# 161                  2444         2444      2444
# ...                   ...          ...       ...
# 305                   621          621       621
# 306                  1414         1414      1414
# 307                   256          256       256
# 308                   257          257       257
# 309                   464          464       464
#
# [131 rows x 3 columns]

# %% [markdown]
# Metrics such as `count`, `unique`, `value_counts` etc. result in actual evaluation

# %%
trips.groupby("Start station")["End station"].count()
# Out:
# Start station
# 157    2108
# 158    1465
# 159    1597
# 160    1121
# 161    2444
#        ...
# 305     621
# 306    1414
# 307     256
# 308     257
# 309     464
# Name: End station, Length: 131, dtype: int64

# %% [markdown]
# `.value_counts()` creates a Series, so we have a two-level index:

# %%
trips.groupby("Start station")["End station"].value_counts()
# Out:
# Start station  End station
# 157            211            165
#                157            125
#                163            112
#                186             96
#                277             94
#                              ...
# 309            275              1
#                290              1
#                292              1
#                294              1
#                301              1
# Name: count, Length: 13969, dtype: int64

# %%
trips.groupby("Start station")["End station"].value_counts()[157]
# Out:
# End station
# 211    165
# 157    125
# 163    112
# 186     96
# 277     94
#       ...
# 249      1
# 265      1
# 268      1
# 275      1
# 307      1
# Name: count, Length: 101, dtype: int64

# %% [markdown]
# We can use groupby to count the number of trips that start on each weekday:

# %%
trips.groupby(trips["Start time"].dt.weekday).count()
# Out:
#             Start station  Start time  End station  End time
# Start time
# 0                   40525       40525        40525     40525
# 1                   36905       36905        36905     36905
# 2                   36465       36465        36465     36465
# 3                   36989       36989        36989     36989
# 4                   35199       35199        35199     35199
# 5                   32122       32122        32122     32122
# 6                   24542       24542        24542     24542

# %%
trips.groupby(trips["Start time"].dt.weekday)["Start station"].count()
# Out:
# Start time
# 0    40525
# 1    36905
# 2    36465
# 3    36989
# 4    35199
# 5    32122
# 6    24542
# Name: Start station, dtype: int64

# %%
by_day = trips.groupby(trips["Start time"].dt.weekday)
grouped = trips.groupby([trips["Start time"].dt.weekday, trips["Start time"].dt.day == trips["End time"].dt.day])
print((grouped.count() / by_day.count())["Start station"].to_string(float_format="{:,.2%}".format))
# Out:
# Start time
# 0           False    0.32%
#             True    99.68%
# 1           False    0.34%
#             True    99.66%
# 2           False    0.28%
#             True    99.72%
# 3           False    0.34%
#             True    99.66%
# 4           False    0.32%
#             True    99.68%
# 5           False    0.47%
#             True    99.53%
# 6           False    0.53%
#             True    99.47%

# %%
by_day = trips.groupby(trips["Start time"].dt.weekday)
by_day.count()
# Out:
#             Start station  Start time  End station  End time
# Start time
# 0                   40525       40525        40525     40525
# 1                   36905       36905        36905     36905
# 2                   36465       36465        36465     36465
# 3                   36989       36989        36989     36989
# 4                   35199       35199        35199     35199
# 5                   32122       32122        32122     32122
# 6                   24542       24542        24542     24542

# %%
grouped = trips.groupby([trips["Start time"].dt.weekday, trips["Start time"].dt.day == trips["End time"].dt.day])
grouped.count()
# Out:
#                   Start station  Start time  End station  End time
# Start time
# 0          False            128         128          128       128
#            True           40397       40397        40397     40397
# 1          False            125         125          125       125
#            True           36780       36780        36780     36780
# 2          False            103         103          103       103
#            True           36362       36362        36362     36362
# 3          False            124         124          124       124
#            True           36865       36865        36865     36865
# 4          False            111         111          111       111
#            True           35088       35088        35088     35088
# 5          False            151         151          151       151
#            True           31971       31971        31971     31971
# 6          False            131         131          131       131
#            True           24411       24411        24411     24411

# %%
s = (grouped.count() / by_day.count())["Start station"]
s
# Out:
# Start time
# 0           False    0.003159
#             True     0.996841
# 1           False    0.003387
#             True     0.996613
# 2           False    0.002825
#             True     0.997175
# 3           False    0.003352
#             True     0.996648
# 4           False    0.003153
#             True     0.996847
# 5           False    0.004701
#             True     0.995299
# 6           False    0.005338
#             True     0.994662
# Name: Start station, dtype: float64

# %%
print(s.to_string(float_format="{:,.2%}".format))
# Out:
# Start time
# 0           False    0.32%
#             True    99.68%
# 1           False    0.34%
#             True    99.66%
# 2           False    0.28%
#             True    99.72%
# 3           False    0.34%
#             True    99.66%
# 4           False    0.32%
#             True    99.68%
# 5           False    0.47%
#             True    99.53%
# 6           False    0.53%
#             True    99.47%

# %% [markdown]
# ## Visualisation

# %% [markdown]
# We can use the `plot` class method to plot our data table:

# %%
trips['Start time'].plot();

# %% [markdown]
# By default, the DataFrame index is used to label the x-axis.

# %% [markdown]
# ## Plotting multiple columns

# %% [markdown]
# Passing multiple columns results in multiple plot lines

# %%
trips[['Start time', 'End time']].head(100).plot();

# %% [markdown]
# In order to get a more meaningful x-axis, we can select a column to be used as the x-axis:

# %%
trips.head(5000).plot.scatter(
    x="Start station", y=["End station"], c="Start time", cmap="viridis"
);

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Build a frequency matrix
heatmap_data = trips.head(5000).groupby(
    ["Start station", "End station"]
).size().unstack(fill_value=0)

# Plot the heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(heatmap_data, cmap="viridis")
plt.title("Trip counts: Start vs End station")
plt.show()

# %% [markdown]
# ## Bar plots

# %% [markdown]
# The documentation of plot reveils many more plotting options:

# %%
trips.plot?
# Out:
# Signature:      trips.plot(*args, **kwargs)
# Type:           PlotAccessor
# String form:    <pandas.plotting._core.PlotAccessor object at 0x000002AF42DD9850>
# File:           c:\users\58263\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages\pandas\plotting\_core.py
# Docstring:
# Make plots of Series or DataFrame.
#
# Uses the backend specified by the
# option ``plotting.backend``. By default, matplotlib is used.
#
# Parameters
# ----------
# data : Series or DataFrame
#     The object for which the method is called.
# x : label or position, default None
#     Only used if data is a DataFrame.
# y : label, position or list of label, positions, default None
#     Allows plotting of one column versus another. Only used if data is a
#     DataFrame.
# kind : str
#     The kind of plot to produce:
#
#     - 'line' : line plot (default)
#     - 'bar' : vertical bar plot
#     - 'barh' : horizontal bar plot
#     - 'hist' : histogram
#     - 'box' : boxplot
#     - 'kde' : Kernel Density Estimation plot
#     - 'density' : same as 'kde'
#     - 'area' : area plot
#     - 'pie' : pie plot
#     - 'scatter' : scatter plot (DataFrame only)
#     - 'hexbin' : hexbin plot (DataFrame only)
# ax : matplotlib axes object, default None
#     An axes of the current figure.
# subplots : bool or sequence of iterables, default False
#     Whether to group columns into subplots:
#
#     - ``False`` : No subplots will be used
#     - ``True`` : Make separate subplots for each column.
#     - sequence of iterables of column labels: Create a subplot for each
#       group of columns. For example `[('a', 'c'), ('b', 'd')]` will
#       create 2 subplots: one with columns 'a' and 'c', and one
#       with columns 'b' and 'd'. Remaining columns that aren't specified
#       will be plotted in additional subplots (one per column).
#
#       .. versionadded:: 1.5.0
#
# sharex : bool, default True if ax is None else False
#     In case ``subplots=True``, share x axis and set some x axis labels
#     to invisible; defaults to True if ax is None otherwise False if
#     an ax is passed in; Be aware, that passing in both an ax and
#     ``sharex=True`` will alter all x axis labels for all axis in a figure.
# sharey : bool, default False
#     In case ``subplots=True``, share y axis and set some y axis labels to invisible.
# layout : tuple, optional
#     (rows, columns) for the layout of subplots.
# figsize : a tuple (width, height) in inches
#     Size of a figure object.
# use_index : bool, default True
#     Use index as ticks for x axis.
# title : str or list
#     Title to use for the plot. If a string is passed, print the string
#     at the top of the figure. If a list is passed and `subplots` is
#     True, print each item in the list above the corresponding subplot.
# grid : bool, default None (matlab style default)
#     Axis grid lines.
# legend : bool or {'reverse'}
#     Place legend on axis subplots.
# style : list or dict
#     The matplotlib line style per column.
# logx : bool or 'sym', default False
#     Use log scaling or symlog scaling on x axis.
#
# logy : bool or 'sym' default False
#     Use log scaling or symlog scaling on y axis.
#
# loglog : bool or 'sym', default False
#     Use log scaling or symlog scaling on both x and y axes.
#
# xticks : sequence
#     Values to use for the xticks.
# yticks : sequence
#     Values to use for the yticks.
# xlim : 2-tuple/list
#     Set the x limits of the current axes.
# ylim : 2-tuple/list
#     Set the y limits of the current axes.
# xlabel : label, optional
#     Name to use for the xlabel on x-axis. Default uses index name as xlabel, or the
#     x-column name for planar plots.
#
#     .. versionchanged:: 2.0.0
#
#         Now applicable to histograms.
#
# ylabel : label, optional
#     Name to use for the ylabel on y-axis. Default will show no ylabel, or the
#     y-column name for planar plots.
#
#     .. versionchanged:: 2.0.0
#
#         Now applicable to histograms.
#
# rot : float, default None
#     Rotation for ticks (xticks for vertical, yticks for horizontal
#     plots).
# fontsize : float, default None
#     Font size for xticks and yticks.
# colormap : str or matplotlib colormap object, default None
#     Colormap to select colors from. If string, load colormap with that
#     name from matplotlib.
# colorbar : bool, optional
#     If True, plot colorbar (only relevant for 'scatter' and 'hexbin'
#     plots).
# position : float
#     Specify relative alignments for bar plot layout.
#     From 0 (left/bottom-end) to 1 (right/top-end). Default is 0.5
#     (center).
# table : bool, Series or DataFrame, default False
#     If True, draw a table using the data in the DataFrame and the data
#     will be transposed to meet matplotlib's default layout.
#     If a Series or DataFrame is passed, use passed data to draw a
#     table.
# yerr : DataFrame, Series, array-like, dict and str
#     See :ref:`Plotting with Error Bars <visualization.errorbars>` for
#     detail.
# xerr : DataFrame, Series, array-like, dict and str
#     Equivalent to yerr.
# stacked : bool, default False in line and bar plots, and True in area plot
#     If True, create stacked plot.
# secondary_y : bool or sequence, default False
#     Whether to plot on the secondary y-axis if a list/tuple, which
#     columns to plot on secondary y-axis.
# mark_right : bool, default True
#     When using a secondary_y axis, automatically mark the column
#     labels with "(right)" in the legend.
# include_bool : bool, default is False
#     If True, boolean values can be plotted.
# backend : str, default None
#     Backend to use instead of the backend specified in the option
#     ``plotting.backend``. For instance, 'matplotlib'. Alternatively, to
#     specify the ``plotting.backend`` for the whole session, set
#     ``pd.options.plotting.backend``.
# **kwargs
#     Options to pass to matplotlib plotting method.
#
# Returns
# -------
# :class:`matplotlib.axes.Axes` or numpy.ndarray of them
#     If the backend is not the default matplotlib one, the return value
#     will be the object returned by the backend.
#
# Notes
# -----
# - See matplotlib documentation online for more on this subject
# - If `kind` = 'bar' or 'barh', you can specify relative alignments
#   for bar plot layout by `position` keyword.
#   From 0 (left/bottom-end) to 1 (right/top-end). Default is 0.5
#   (center)
#
# Examples
# --------
# For Series:
#
# .. plot::
#     :context: close-figs
#
#     >>> ser = pd.Series([1, 2, 3, 3])
#     >>> plot = ser.plot(kind='hist', title="My plot")
#
# For DataFrame:
#
# .. plot::
#     :context: close-figs
#
#     >>> df = pd.DataFrame({'length': [1.5, 0.5, 1.2, 0.9, 3],
#     ...                   'width': [0.7, 0.2, 0.15, 0.2, 1.1]},
#     ...                   index=['pig', 'rabbit', 'duck', 'chicken', 'horse'])
#     >>> plot = df.plot(title="DataFrame Plot")
#
# For SeriesGroupBy:
#
# .. plot::
#     :context: close-figs
#
#     >>> lst = [-1, -2, -3, 1, 2, 3]
#     >>> ser = pd.Series([1, 2, 2, 4, 6, 6], index=lst)
#     >>> plot = ser.groupby(lambda x: x > 0).plot(title="SeriesGroupBy Plot")
#
# For DataFrameGroupBy:
#
# .. plot::
#     :context: close-figs
#
#     >>> df = pd.DataFrame({"col1" : [1, 2, 3, 4],
#     ...                   "col2" : ["A", "B", "A", "B"]})
#     >>> plot = df.groupby("col2").plot(kind="bar", title="DataFrameGroupBy Plot")
# Call docstring:
# Make plots of Series or DataFrame.
#
# Uses the backend specified by the
# option ``plotting.backend``. By default, matplotlib is used.
#
# Parameters
# ----------
# data : Series or DataFrame
#     The object for which the method is called.
# x : label or position, default None
#     Only used if data is a DataFrame.
# y : label, position or list of label, positions, default None
#     Allows plotting of one column versus another. Only used if data is a
#     DataFrame.
# kind : str
#     The kind of plot to produce:
#
#     - 'line' : line plot (default)
#     - 'bar' : vertical bar plot
#     - 'barh' : horizontal bar plot
#     - 'hist' : histogram
#     - 'box' : boxplot
#     - 'kde' : Kernel Density Estimation plot
#     - 'density' : same as 'kde'
#     - 'area' : area plot
#     - 'pie' : pie plot
#     - 'scatter' : scatter plot (DataFrame only)
#     - 'hexbin' : hexbin plot (DataFrame only)
# ax : matplotlib axes object, default None
#     An axes of the current figure.
# subplots : bool or sequence of iterables, default False
#     Whether to group columns into subplots:
#
#     - ``False`` : No subplots will be used
#     - ``True`` : Make separate subplots for each column.
#     - sequence of iterables of column labels: Create a subplot for each
#       group of columns. For example `[('a', 'c'), ('b', 'd')]` will
#       create 2 subplots: one with columns 'a' and 'c', and one
#       with columns 'b' and 'd'. Remaining columns that aren't specified
#       will be plotted in additional subplots (one per column).
#
#       .. versionadded:: 1.5.0
#
# sharex : bool, default True if ax is None else False
#     In case ``subplots=True``, share x axis and set some x axis labels
#     to invisible; defaults to True if ax is None otherwise False if
#     an ax is passed in; Be aware, that passing in both an ax and
#     ``sharex=True`` will alter all x axis labels for all axis in a figure.
# sharey : bool, default False
#     In case ``subplots=True``, share y axis and set some y axis labels to invisible.
# layout : tuple, optional
#     (rows, columns) for the layout of subplots.
# figsize : a tuple (width, height) in inches
#     Size of a figure object.
# use_index : bool, default True
#     Use index as ticks for x axis.
# title : str or list
#     Title to use for the plot. If a string is passed, print the string
#     at the top of the figure. If a list is passed and `subplots` is
#     True, print each item in the list above the corresponding subplot.
# grid : bool, default None (matlab style default)
#     Axis grid lines.
# legend : bool or {'reverse'}
#     Place legend on axis subplots.
# style : list or dict
#     The matplotlib line style per column.
# logx : bool or 'sym', default False
#     Use log scaling or symlog scaling on x axis.
#
# logy : bool or 'sym' default False
#     Use log scaling or symlog scaling on y axis.
#
# loglog : bool or 'sym', default False
#     Use log scaling or symlog scaling on both x and y axes.
#
# xticks : sequence
#     Values to use for the xticks.
# yticks : sequence
#     Values to use for the yticks.
# xlim : 2-tuple/list
#     Set the x limits of the current axes.
# ylim : 2-tuple/list
#     Set the y limits of the current axes.
# xlabel : label, optional
#     Name to use for the xlabel on x-axis. Default uses index name as xlabel, or the
#     x-column name for planar plots.
#
#     .. versionchanged:: 2.0.0
#
#         Now applicable to histograms.
#
# ylabel : label, optional
#     Name to use for the ylabel on y-axis. Default will show no ylabel, or the
#     y-column name for planar plots.
#
#     .. versionchanged:: 2.0.0
#
#         Now applicable to histograms.
#
# rot : float, default None
#     Rotation for ticks (xticks for vertical, yticks for horizontal
#     plots).
# fontsize : float, default None
#     Font size for xticks and yticks.
# colormap : str or matplotlib colormap object, default None
#     Colormap to select colors from. If string, load colormap with that
#     name from matplotlib.
# colorbar : bool, optional
#     If True, plot colorbar (only relevant for 'scatter' and 'hexbin'
#     plots).
# position : float
#     Specify relative alignments for bar plot layout.
#     From 0 (left/bottom-end) to 1 (right/top-end). Default is 0.5
#     (center).
# table : bool, Series or DataFrame, default False
#     If True, draw a table using the data in the DataFrame and the data
#     will be transposed to meet matplotlib's default layout.
#     If a Series or DataFrame is passed, use passed data to draw a
#     table.
# yerr : DataFrame, Series, array-like, dict and str
#     See :ref:`Plotting with Error Bars <visualization.errorbars>` for
#     detail.
# xerr : DataFrame, Series, array-like, dict and str
#     Equivalent to yerr.
# stacked : bool, default False in line and bar plots, and True in area plot
#     If True, create stacked plot.
# secondary_y : bool or sequence, default False
#     Whether to plot on the secondary y-axis if a list/tuple, which
#     columns to plot on secondary y-axis.
# mark_right : bool, default True
#     When using a secondary_y axis, automatically mark the column
#     labels with "(right)" in the legend.
# include_bool : bool, default is False
#     If True, boolean values can be plotted.
# backend : str, default None
#     Backend to use instead of the backend specified in the option
#     ``plotting.backend``. For instance, 'matplotlib'. Alternatively, to
#     specify the ``plotting.backend`` for the whole session, set
#     ``pd.options.plotting.backend``.
# **kwargs
#     Options to pass to matplotlib plotting method.
#
# Returns
# -------
# :class:`matplotlib.axes.Axes` or numpy.ndarray of them
#     If the backend is not the default matplotlib one, the return value
#     will be the object returned by the backend.
#
# Notes
# -----
# - See matplotlib documentation online for more on this subject
# - If `kind` = 'bar' or 'barh', you can specify relative alignments
#   for bar plot layout by `position` keyword.
#   From 0 (left/bottom-end) to 1 (right/top-end). Default is 0.5
#   (center)
#
# Examples
# --------
# For Series:
#
# .. plot::
#     :context: close-figs
#
#     >>> ser = pd.Series([1, 2, 3, 3])
#     >>> plot = ser.plot(kind='hist', title="My plot")
#
# For DataFrame:
#
# .. plot::
#     :context: close-figs
#
#     >>> df = pd.DataFrame({'length': [1.5, 0.5, 1.2, 0.9, 3],
#     ...                   'width': [0.7, 0.2, 0.15, 0.2, 1.1]},
#     ...                   index=['pig', 'rabbit', 'duck', 'chicken', 'horse'])
#     >>> plot = df.plot(title="DataFrame Plot")
#
# For SeriesGroupBy:
#
# .. plot::
#     :context: close-figs
#
#     >>> lst = [-1, -2, -3, 1, 2, 3]
#     >>> ser = pd.Series([1, 2, 2, 4, 6, 6], index=lst)
#     >>> plot = ser.groupby(lambda x: x > 0).plot(title="SeriesGroupBy Plot")
#
# For DataFrameGroupBy:
#
# .. plot::
#     :context: close-figs
#
#     >>> df = pd.DataFrame({"col1" : [1, 2, 3, 4],
#     ...                   "col2" : ["A", "B", "A", "B"]})
#     >>> plot = df.groupby("col2").plot(kind="bar", title="DataFrameGroupBy Plot")

# %% [markdown]
# For example, let's create a bar plot:

# %%
trips.head(10).plot(x='Start time', y=['Start station', 'End station'], kind='bar');

# %% [markdown]
# ## Histograms

# %%
trips['Start station'].plot(kind='hist');

# %%
trips['Start time'].dt.hour.plot(kind='hist', bins=range(25));

# %%
trips['Start time'].dt.weekday.plot.hist(bins=range(8));

# %% [markdown]
# 'unstack' takes a two-level index and promotes one level to column names

# %%
grouped.count()["Start station"]
# Out:
# Start time
# 0           False      128
#             True     40397
# 1           False      125
#             True     36780
# 2           False      103
#             True     36362
# 3           False      124
#             True     36865
# 4           False      111
#             True     35088
# 5           False      151
#             True     31971
# 6           False      131
#             True     24411
# Name: Start station, dtype: int64

# %%
grouped.count()["Start station"].unstack(1)
# Out:
#             False  True
# Start time
# 0             128  40397
# 1             125  36780
# 2             103  36362
# 3             124  36865
# 4             111  35088
# 5             151  31971
# 6             131  24411

# %%
import calendar
import matplotlib.pyplot as plt

# %%
grouped.count()["Start station"].unstack(1).plot(kind="bar", stacked=True)
plt.xlabel("Weekday");
plt.xticks(range(7), calendar.day_name);

# %%
(grouped.count() / by_day.count())["Start station"].unstack(1)[False].plot.bar()
plt.xlabel("Weekday");
plt.xticks(range(7), calendar.day_name);

# %% [markdown]
# ## Saving data

# %% [markdown]
# DataFrames can be saved to various formats.
#
# For exporting to a spreadsheet compatible format (e.g. Excel), you can export as CSV file:

# %%
data = trips[['Start station', 'End station']].head(10)

with open("start_stop_stations.csv", "w") as file:
    csv =  data.to_csv()
    print(csv)
    file.write(csv)
# Out:
# ,Start station,End station
# 0,283,238
# 1,169,175
# 2,211,162
# 3,200,163
# 4,157,163
# 5,177,179
# 6,257,199
# 7,191,191
# 8,191,167
# 9,181,251

# %% [markdown]
# Notice that it includes the index

# %%
data = trips[['Start station', 'End station']].head(10)

with open("start_stop_stations.csv", "w") as file:
    csv =  data.to_csv(index_label="index")
    print(csv)
    file.write(csv)
# Out:
# index,Start station,End station
# 0,283,238
# 1,169,175
# 2,211,162
# 3,200,163
# 4,157,163
# 5,177,179
# 6,257,199
# 7,191,191
# 8,191,167
# 9,181,251

# %% [markdown]
# ## Usefull trick for your master thesis

# %% [markdown]
# **Goal**: If you do data analyis as part of your research, it is usefull to generate any figures/tables directly from your analytics scripts.
#
# **Solution**: Pandas can automatically generate Latex tables:

# %%
with open('table.tex', 'w') as file:
    latex = data.to_latex()
    print(latex)
    file.write(latex)
# Out:
# \begin{tabular}{lrr}
# \toprule
#  & Start station & End station \\
# \midrule
# 0 & 283 & 238 \\
# 1 & 169 & 175 \\
# 2 & 211 & 162 \\
# 3 & 200 & 163 \\
# 4 & 157 & 163 \\
# 5 & 177 & 179 \\
# 6 & 257 & 199 \\
# 7 & 191 & 191 \\
# 8 & 191 & 167 \\
# 9 & 181 & 251 \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# ## Simple data analytics: What are the most used bike stations?

# %% [markdown]
# **Approach**: For each bike station usage, the station's `id` occurs in a new row in the `Start station` column.
# In order to find how often a bike station is used, we count how often the station id occurs in the `Start station` column. By sorting these counds from high to low, we get the most used bike stations.
#
# The function `value_counts` does exactly what we need:

# %%
trips['Start station'].value_counts()[10:]
# Out:
# Start station
# 229    3771
# 210    3586
# 262    3568
# 164    3428
# 287    3289
#        ...
# 249     270
# 308     257
# 188     256
# 307     256
# 256     153
# Name: count, Length: 121, dtype: int64

# %% [markdown]
# Let's plot the result in the bar chart:

# %%
trips['Start station'].value_counts()[:50].plot(kind='bar');
plt.grid(False);

# %% [markdown]
# ## Concatenating DataFrames 1/2

# %% [markdown]
# The data so far only contained the statistics for October 2016:

# %%
trips_oct["Start time"].min(), trips_oct["Start time"].max()
# Out:
# (Timestamp('2016-10-01 04:00:08+0000', tz='UTC'),
#  Timestamp('2016-10-31 22:59:10+0000', tz='UTC'))

# %% [markdown]
# Let us load the data for September 2016:

# %%
trips_sep = pd.read_csv(
    "data/bysykkel/trips-2016.9.1-2016.9.30.csv",
    sep=",",
    parse_dates=["Start time", "End time"],
    date_parser=lambda col: pd.to_datetime(col, utc=True),
)
# perform transform to ensure we have integer stations
trips_sep = trips_sep.dropna().astype({"End station": int})
# Out:
# C:\Users\pvwol\AppData\Local\Temp\ipykernel_15968\913141250.py:1: FutureWarning: The argument 'date_parser' is deprecated and will be removed in a future version. Please use 'date_format' instead, or read your data in as 'object' dtype and then call 'to_datetime'.
#   trips_sep = pd.read_csv(

# %% [markdown]
# ## Concatenating DataFrames 2/2

# %% [markdown]
# To concatenate the two, we use the `concat` function:

# %%
trips = pd.concat([trips_sep, trips_oct]).reset_index()
trips
# Out:
#          index  Start station                Start time  End station  \
# 0            0            291 2016-09-01 04:00:02+00:00        301.0
# 1            1            262 2016-09-01 04:00:07+00:00        292.0
# 2            2            277 2016-09-01 04:00:07+00:00        163.0
# 3            3            174 2016-09-01 04:00:07+00:00        157.0
# 4            4            257 2016-09-01 04:00:13+00:00        257.0
# ...        ...            ...                       ...          ...
# 620402  242753            284 2016-10-31 22:53:30+00:00        164.0
# 620403  242754            218 2016-10-31 22:53:48+00:00        292.0
# 620404  242755            204 2016-10-31 22:54:28+00:00        277.0
# 620405  242756            204 2016-10-31 22:56:57+00:00        201.0
# 620406  242757            268 2016-10-31 22:59:10+00:00        299.0
#
#                         End time
# 0      2016-09-01 04:06:06+00:00
# 1      2016-09-01 04:15:43+00:00
# 2      2016-09-01 04:03:07+00:00
# 3      2016-09-01 04:11:33+00:00
# 4      2016-09-01 05:36:16+00:00
# ...                          ...
# 620402 2016-10-31 23:04:13+00:00
# 620403 2016-10-31 23:09:17+00:00
# 620404 2016-10-31 23:01:59+00:00
# 620405 2016-10-31 23:02:16+00:00
# 620406 2016-10-31 23:04:55+00:00
#
# [620407 rows x 5 columns]

# %% [markdown]
# Let's check that we indeed have the full range:

# %%
trips["Start time"].min(), trips["Start time"].max()
# Out:
# (Timestamp('2016-09-01 04:00:02+0000', tz='UTC'),
#  Timestamp('2016-10-31 22:59:10+0000', tz='UTC'))

# %%
len(trips_sep), len(trips_oct), len(trips)
# Out:
# (377649, 242758, 620407)

# %% [markdown]
# # Linking multiple tables

# %% [markdown]
# **Problem**: At the moment, the bike stations are anonymous ids. It would be usefull to have additional meta-data (location name, GPS coordinates, ...) attached.
#
# Luckily we have a file that contains this information:

# %%
import json
with open("data/bysykkel/stations.json") as f:
    station_info = json.load(f)
station_info["stations"][:2]
# Out:
# [{'id': 157,
#   'in_service': True,
#   'title': 'Nylandsveien',
#   'subtitle': 'mellom Norbygata og Urtegata',
#   'number_of_locks': 30,
#   'center': {'latitude': 59.91562, 'longitude': 10.762248},
#   'bounds': [{'latitude': 59.915418602160436, 'longitude': 10.762068629264832},
#    {'latitude': 59.91565254992276, 'longitude': 10.762672126293182},
#    {'latitude': 59.915807169665264, 'longitude': 10.762433409690855},
#    {'latitude': 59.91557994562126, 'longitude': 10.761821866035461},
#    {'latitude': 59.915418602160436, 'longitude': 10.762068629264832}]},
#  {'id': 158,
#   'in_service': True,
#   'title': 'Bentsebrugata',
#   'subtitle': 'rett over busstoppet',
#   'number_of_locks': 24,
#   'center': {'latitude': 59.939228, 'longitude': 10.75917},
#   'bounds': [{'latitude': 59.93914016847159, 'longitude': 10.758990666291977},
#    {'latitude': 59.93914016847159, 'longitude': 10.759349333708023},
#    {'latitude': 59.939319831528415, 'longitude': 10.759349333708023},
#    {'latitude': 59.939319831528415, 'longitude': 10.758990666291977},
#    {'latitude': 59.93914016847159, 'longitude': 10.758990666291977}]}]

# %% [markdown]
# ## Reading the station information 1/3

# %% [markdown]
# The obvious thing would be to use `pd.read_json`:

# %%
bike_stations = pd.read_json('data/bysykkel/stations')
# Out:
# C:\Users\pvwol\AppData\Local\Temp\ipykernel_15968\1640611096.py:1: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   bike_stations = pd.read_json('data/bysykkel/stations')
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 bike_stations = pd.read_json('data/bysykkel/stations')
#
# File c:\Users\pvwol\anaconda3\Lib\site-packages\pandas\io\json\_json.py:815, in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, precise_float, date_unit, encoding, encoding_errors, lines, chunksize, compression, nrows, storage_options, dtype_backend, engine)
#     813     return json_reader
#     814 else:
# --> 815     return json_reader.read()
#
# File c:\Users\pvwol\anaconda3\Lib\site-packages\pandas\io\json\_json.py:1025, in JsonReader.read(self)
#    1023         obj = self._get_object_parser(self._combine_lines(data_lines))
#    1024 else:
# -> 1025     obj = self._get_object_parser(self.data)
#    1026 if self.dtype_backend is not lib.no_default:
#    1027     return obj.convert_dtypes(
#    1028         infer_objects=False, dtype_backend=self.dtype_backend
#    1029     )
#
# File c:\Users\pvwol\anaconda3\Lib\site-packages\pandas\io\json\_json.py:1051, in JsonReader._get_object_parser(self, json)
#    1049 obj = None
#    1050 if typ == "frame":
# -> 1051     obj = FrameParser(json, **kwargs).parse()
#    1053 if typ == "series" or obj is None:
#    1054     if not isinstance(dtype, bool):
#
# File c:\Users\pvwol\anaconda3\Lib\site-packages\pandas\io\json\_json.py:1187, in Parser.parse(self)
#    1185 @final
#    1186 def parse(self):
# -> 1187     self._parse()
#    1189     if self.obj is None:
#    1190         return None
#
# File c:\Users\pvwol\anaconda3\Lib\site-packages\pandas\io\json\_json.py:1403, in FrameParser._parse(self)
#    1399 orient = self.orient
#    1401 if orient == "columns":
#    1402     self.obj = DataFrame(
# -> 1403         ujson_loads(json, precise_float=self.precise_float), dtype=None
#    1404     )
#    1405 elif orient == "split":
#    1406     decoded = {
#    1407         str(k): v
#    1408         for k, v in ujson_loads(json, precise_float=self.precise_float).items()
#    1409     }
#
# ValueError: Expected object or value

# %% [markdown]
# Does not work because `read_json` expects the json to have a specific structure.

# %% [markdown]
# ## Reading the station information 2/3

# %% [markdown]
# Instead we load the data with the `json` module:

# %%
import json
with open('data/bysykkel/stations.json', 'r') as f:
    stations_json = json.load(f)
print(stations_json.keys())
# Out:
# dict_keys(['stations'])

# %% [markdown]
# We are interested in the node `stations`, so let's extract this:

# %%
station_json = stations_json['stations']
print(len(station_json))
station_json[:2]
# Out:
# 130
# [{'id': 157,
#   'in_service': True,
#   'title': 'Nylandsveien',
#   'subtitle': 'mellom Norbygata og Urtegata',
#   'number_of_locks': 30,
#   'center': {'latitude': 59.91562, 'longitude': 10.762248},
#   'bounds': [{'latitude': 59.915418602160436, 'longitude': 10.762068629264832},
#    {'latitude': 59.91565254992276, 'longitude': 10.762672126293182},
#    {'latitude': 59.915807169665264, 'longitude': 10.762433409690855},
#    {'latitude': 59.91557994562126, 'longitude': 10.761821866035461},
#    {'latitude': 59.915418602160436, 'longitude': 10.762068629264832}]},
#  {'id': 158,
#   'in_service': True,
#   'title': 'Bentsebrugata',
#   'subtitle': 'rett over busstoppet',
#   'number_of_locks': 24,
#   'center': {'latitude': 59.939228, 'longitude': 10.75917},
#   'bounds': [{'latitude': 59.93914016847159, 'longitude': 10.758990666291977},
#    {'latitude': 59.93914016847159, 'longitude': 10.759349333708023},
#    {'latitude': 59.939319831528415, 'longitude': 10.759349333708023},
#    {'latitude': 59.939319831528415, 'longitude': 10.758990666291977},
#    {'latitude': 59.93914016847159, 'longitude': 10.758990666291977}]}]

# %% [markdown]
# ## Reading in station infromation 3/3

# %% [markdown]
# We can now use the `pandas.json_normalize` function to read in the entire dataset:

# %%
stations = pd.json_normalize(station_json)
stations
# Out:
#       id  in_service                         title  \
# 0    157        True                  Nylandsveien
# 1    158        True                 Bentsebrugata
# 2    159        True     Hans Nielsen Hauges plass
# 3    160        True                 Sjøsiden vest
# 4    161        True      St. Hanshaugen park vest
# ..   ...         ...                           ...
# 125  305        True      Georg Morgenstiernes hus
# 126  306        True                    Møllergata
# 127  307        True   Bak Niels Treschows hus sør
# 128  308        True     Blindern studentparkering
# 129  309        True  Bak Niels Treschows hus nord
#
#                             subtitle  number_of_locks  \
# 0       mellom Norbygata og Urtegata               30
# 1               rett over busstoppet               24
# 2    Mellom Åsengata og Nordkappgata               21
# 3                   nærmest fontenen               25
# 4       ved busstoppet Colletts gate               20
# ..                               ...              ...
# 125              ved Moltke Moes vei               45
# 126           rett over Youngstorget               30
# 127            nærmest trikkestoppet               42
# 128  rett ved Blindern Studenterhjem               42
# 129        nærmest parkeringsplassen               42
#
#                                                 bounds  center.latitude  \
# 0    [{'latitude': 59.915418602160436, 'longitude':...        59.915620
# 1    [{'latitude': 59.93914016847159, 'longitude': ...        59.939228
# 2    [{'latitude': 59.93915186056247, 'longitude': ...        59.939238
# 3    [{'latitude': 59.9101839259445, 'longitude': 1...        59.910215
# 4    [{'latitude': 59.926781168471585, 'longitude':...        59.926872
# ..                                                 ...              ...
# 125  [{'latitude': 59.938893893998106, 'longitude':...        59.938998
# 126  [{'latitude': 59.91530028312405, 'longitude': ...        59.915290
# 127  [{'latitude': 59.94238164705898, 'longitude': ...        59.942525
# 128  [{'latitude': 59.9409978752237, 'longitude': 1...        59.940930
# 129  [{'latitude': 59.94258316241174, 'longitude': ...        59.942725
#
#      center.longitude
# 0           10.762248
# 1           10.759170
# 2           10.774279
# 3           10.751687
# 4           10.738456
# ..                ...
# 125         10.723075
# 126         10.748453
# 127         10.723352
# 128         10.720666
# 129         10.722889
#
# [130 rows x 8 columns]

# %% [markdown]
# ## Setting the index
#
# Before extracting data from the `DataFrame`, it is good practice to assign a column with unique values as the index of the dataframe (if possible). For the stations DataFrame, the `id` column is a natural choice:

# %%
stations = stations.set_index('id')
stations
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 stations = stations.set_index('id')
#       2 stations
#
# NameError: name 'stations' is not defined

# %% [markdown]
# The index will be used, e.g. for row labels when plotting:

# %%
stations.head(10)["number_of_locks"].plot(kind="bar");

# %% [markdown]
# ### Removing columns from DataFrames

# %% [markdown]
# Some of the columns are not useful. We can remove columns from a DataFrame with:
# ```python
# Dataframe.drop([Column Name or list], axis=1)
# ```
# Lets reduce our stations to the usefull columns:

# %%
stations = stations.drop(["bounds", "subtitle"], axis=1)   # axis=0 drops rows
stations.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 stations = stations.drop(["bounds", "subtitle"], axis=1)   # axis=0 drops rows
#       2 stations.head()
#
# NameError: name 'stations' is not defined

# %% [markdown]
# **Alternative**: Use `.loc` to select a subset of a DataFrame
# ```python
# DataFrame.loc[startrow:endrow,startcolumn:endcolumn]
# ```

# %% [markdown]
# ## Adding computed columns

# %% [markdown]
# Sometimes it is usefull to add a new column based on calculations.
#
# **Syntax**:
# ```python
# Dataframe.apply(function, axis=1)  # Results in a Series
# ```

# %% [markdown]
# **Example**: Add a column with the distance from the station to Oslo center.
#
# First we compute a Series with the distance values:®

# %%
from numpy import cos, arcsin, sqrt, pi

oslo_center = 59.9127, 10.7461 # oslo center latitude, longitude

def distance_to_oslo_center(row):
    """ Computes the distance of a lat/lon"""

    lat_station = row["center.latitude"]
    lon_station = row["center.longitude"]

    lat_sentrum, lon_sentrum = oslo_center

    degrees = pi / 180  # convert degrees to radians
    a = (
        0.5
        - (cos((lat_sentrum - lat_station) * degrees) / 2)
        + (
            cos(lat_sentrum * degrees)
            * cos(lat_station * degrees)
            * (1 - cos((lon_station - lon_sentrum) * degrees))
            / 2
        )
    )
    return 12742 * arcsin(sqrt(a))  # 2 * R * asin...


distance = stations.apply(distance_to_oslo_center, axis=1)
distance
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 27
#      14     a = (
#      15         0.5
#      16         - (cos((lat_sentrum - lat_station) * degrees) / 2)
#    (...)
#      22         )
#      23     )
#      24     return 12742 * arcsin(sqrt(a))  # 2 * R * asin...
# ---> 27 distance = stations.apply(distance_to_oslo_center, axis=1)
#      28 distance
#
# NameError: name 'stations' is not defined

# %% [markdown]
# Then we add that serie to the DataFrame:

# %%
stations["distance_to_oslo_center"] = distance
stations
# Out:
#      in_service                         title  number_of_locks  \
# id
# 157        True                  Nylandsveien               30
# 158        True                 Bentsebrugata               24
# 159        True     Hans Nielsen Hauges plass               21
# 160        True                 Sjøsiden vest               25
# 161        True      St. Hanshaugen park vest               20
# ..          ...                           ...              ...
# 305        True      Georg Morgenstiernes hus               45
# 306        True                    Møllergata               30
# 307        True   Bak Niels Treschows hus sør               42
# 308        True     Blindern studentparkering               42
# 309        True  Bak Niels Treschows hus nord               42
#
#      center.latitude  center.longitude  distance_to_oslo_center
# id
# 157        59.915620         10.762248                 0.956887
# 158        59.939228         10.759170                 3.038354
# 159        59.939238         10.774279                 3.342640
# 160        59.910215         10.751687                 0.416360
# 161        59.926872         10.738456                 1.632424
# ..               ...               ...                      ...
# 305        59.938998         10.723075                 3.193283
# 306        59.915290         10.748453                 0.316456
# 307        59.942525         10.723352                 3.550350
# 308        59.940930         10.720666                 3.444120
# 309        59.942725         10.722889                 3.580368
#
# [130 rows x 6 columns]

# %% [markdown]
# ### Min, max mean of Series data:

# %% [markdown]
# We can use mathematical functions such as `min`, `max` or `mean` to get statistical information about a column:

# %% [markdown]
# Minimum number of locks:

# %%
stations["number_of_locks"].min()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 stations["number_of_locks"].min()
#
# NameError: name 'stations' is not defined

# %% [markdown]
# Maximum number of locks:

# %%
stations["number_of_locks"].max()
# Out:
# 48

# %% [markdown]
# Average number of locks:

# %%
stations["number_of_locks"].mean()
# Out:
# np.float64(22.29230769230769)

# %% [markdown]
# ## Plotting maps
#
# It would be nice to plot the stations on a map.

# %%
from ipywidgets import HTML
from ipyleaflet import Map, Marker, basemaps, basemap_to_tiles

oslo_map = Map(
    center=oslo_center,
    zoom=13,
)


def add_marker(row):
    center = row["center.latitude"], row["center.longitude"]
    m = Marker(
        location=center,
        title=f"{row.name} {row['title']}",
    )

    oslo_map.add_layer(m)
    m.popup = HTML(f"{m.title}<br/>{row.distance_to_oslo_center:.2f} km to center")


stations.apply(add_marker, axis=1)
oslo_map.save("my_2024_map.html")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 5
#       1 from ipywidgets import HTML
#       2 from ipyleaflet import Map, Marker, basemaps, basemap_to_tiles
#       4 oslo_map = Map(
# ----> 5     center=oslo_center,
#       6     zoom=13,
#       7 )
#      10 def add_marker(row):
#      11     center = row["center.latitude"], row["center.longitude"]
#
# NameError: name 'oslo_center' is not defined

# %% [markdown]
# # Merging Panda objects
#
# So far our bike statistics stores the bike stations as integers:

# %%
trips.head()
# Out:
#    Start station                Start time  End station  \
# 0            283 2016-10-01 04:00:08+00:00          238
# 1            169 2016-10-01 04:00:41+00:00          175
# 2            211 2016-10-01 04:01:02+00:00          162
# 3            200 2016-10-01 04:01:20+00:00          163
# 4            157 2016-10-01 04:02:16+00:00          163
#
#                    End time
# 0 2016-10-01 04:09:47+00:00
# 1 2016-10-01 04:11:07+00:00
# 2 2016-10-01 04:15:52+00:00
# 3 2016-10-01 04:15:04+00:00
# 4 2016-10-01 04:04:29+00:00

# %% [markdown]
# Wouldn't it be nice to add the station information?
#
# We achieve this by merging the information in the `stations` DataFrame into the `trips_sep_oct` DataFrame. The syntax for merging two tables with the most important arguments is:
#
# ```python
# pd.merge(left, right, how='inner', left_on=None, right_on=None)
# ```
# The arguments mean the following:
# * `left`: A DataFrame object
# * `right`: Another DataFrame object
# * `left_on`: Columns from the left DataFrame to use as keys. Can either be column names or arrays with length equal to the length of the DataFrame
# * `right_on`: Columns from the right DataFrame to use as keys. Can either be column names or arrays with length equal to the length of the DataFrame
# * `how`: One of 'left', 'right', 'outer', 'inner'. Defaults to inner. See below for more detailed description of each method:

# %% [markdown]
# ###  A simple demo on merging

# %%
purchases = pd.DataFrame({"product": ["apples", "pears"], "purchases": [1, 3]})
purchases
# Out:
#   product  purchases
# 0  apples          1
# 1   pears          3

# %%
prices = pd.DataFrame({"product": ["apples", "pears"], "price": [5.5, 1.2]})
prices
# Out:
#   product  price
# 0  apples    5.5
# 1   pears    1.2

# %%
pd.merge(purchases, prices, how="right", left_on="product", right_on="product")
# Out:
#   product  purchases  price
# 0  apples          1    5.5
# 1   pears          3    1.2

# %% [markdown]
# ### Back to the Oslo Bysykkel example

# %% [markdown]
# Let's try it out. First, lets check the names of our columns again:

# %%
print(trips.dtypes)
# Out:
# Start station                  int64
# Start time       datetime64[ns, UTC]
# End station                    int64
# End time         datetime64[ns, UTC]
# dtype: object

# %%
print(stations.dtypes)
# Out:
# in_service                    bool
# title                       object
# number_of_locks              int64
# center.latitude            float64
# center.longitude           float64
# distance_to_oslo_center    float64
# dtype: object

# %% [markdown]
# We want to merge in the columns `trips["Start station"]` with the index for `stations`. The merge call is therefore:

# %%
merged_bike_stats = pd.merge(
    trips, stations, how="left", left_on="Start station", right_index=True
)
merged_bike_stats
# Out:
#         Start station                Start time  End station  \
# 0                 283 2016-10-01 04:00:08+00:00          238
# 1                 169 2016-10-01 04:00:41+00:00          175
# 2                 211 2016-10-01 04:01:02+00:00          162
# 3                 200 2016-10-01 04:01:20+00:00          163
# 4                 157 2016-10-01 04:02:16+00:00          163
# ...               ...                       ...          ...
# 242753            284 2016-10-31 22:53:30+00:00          164
# 242754            218 2016-10-31 22:53:48+00:00          292
# 242755            204 2016-10-31 22:54:28+00:00          277
# 242756            204 2016-10-31 22:56:57+00:00          201
# 242757            268 2016-10-31 22:59:10+00:00          299
#
#                         End time in_service             title  \
# 0      2016-10-01 04:09:47+00:00       True        Marienlyst
# 1      2016-10-01 04:11:07+00:00       True      Bogstadveien
# 2      2016-10-01 04:15:52+00:00       True         Oslo City
# 3      2016-10-01 04:15:04+00:00       True      TÃ¸yen skole
# 4      2016-10-01 04:04:29+00:00       True      Nylandsveien
# ...                          ...        ...               ...
# 242753 2016-10-31 23:04:13+00:00       True  Majorstuen skole
# 242754 2016-10-31 23:09:17+00:00       True          Briskeby
# 242755 2016-10-31 23:01:59+00:00       True        PalÃ©haven
# 242756 2016-10-31 23:02:16+00:00       True        PalÃ©haven
# 242757 2016-10-31 23:04:55+00:00       True       Stensparken
#
#         number_of_locks  center.latitude  center.longitude  \
# 0                  12.0        59.932449         10.721813
# 1                  18.0        59.924729         10.724579
# 2                  12.0        59.912779         10.751116
# 3                  15.0        59.914990         10.773942
# 4                  30.0        59.915620         10.762248
# ...                 ...              ...               ...
# 242753             27.0        59.929829         10.713032
# 242754             15.0        59.920187         10.717955
# 242755             48.0        59.910287         10.750012
# 242756             48.0        59.910287         10.750012
# 242757             15.0        59.927141         10.730917
#
#         distance_to_oslo_center
# 0                      2.579575
# 1                      1.796597
# 2                      0.279750
# 3                      1.572725
# 4                      0.956887
# ...                         ...
# 242753                 2.650263
# 242754                 1.775960
# 242755                 0.345761
# 242756                 0.345761
# 242757                 1.815077
#
# [242747 rows x 10 columns]

# %% [markdown]
# Let's check that we still have all the data rows:

# %%
print(len(merged_bike_stats))
print(len(trips))
# Out:
# 242747
# 242747

# %% [markdown]
# Let us do the same for `End station`. To avoid overlapping column names, we use the `suffixes`:

# %%
merged_bike_stats2 = pd.merge(
    merged_bike_stats,
    stations,
    how="left",
    left_on="End station",
    right_index=True,
    suffixes=("_start", "_end"),
)
merged_bike_stats2
# Out:
#         Start station                Start time  End station  \
# 0                 283 2016-10-01 04:00:08+00:00          238
# 1                 169 2016-10-01 04:00:41+00:00          175
# 2                 211 2016-10-01 04:01:02+00:00          162
# 3                 200 2016-10-01 04:01:20+00:00          163
# 4                 157 2016-10-01 04:02:16+00:00          163
# ...               ...                       ...          ...
# 242753            284 2016-10-31 22:53:30+00:00          164
# 242754            218 2016-10-31 22:53:48+00:00          292
# 242755            204 2016-10-31 22:54:28+00:00          277
# 242756            204 2016-10-31 22:56:57+00:00          201
# 242757            268 2016-10-31 22:59:10+00:00          299
#
#                         End time in_service_start       title_start  \
# 0      2016-10-01 04:09:47+00:00             True        Marienlyst
# 1      2016-10-01 04:11:07+00:00             True      Bogstadveien
# 2      2016-10-01 04:15:52+00:00             True         Oslo City
# 3      2016-10-01 04:15:04+00:00             True      TÃ¸yen skole
# 4      2016-10-01 04:04:29+00:00             True      Nylandsveien
# ...                          ...              ...               ...
# 242753 2016-10-31 23:04:13+00:00             True  Majorstuen skole
# 242754 2016-10-31 23:09:17+00:00             True          Briskeby
# 242755 2016-10-31 23:01:59+00:00             True        PalÃ©haven
# 242756 2016-10-31 23:02:16+00:00             True        PalÃ©haven
# 242757 2016-10-31 23:04:55+00:00             True       Stensparken
#
#         number_of_locks_start  center.latitude_start  center.longitude_start  \
# 0                        12.0              59.932449               10.721813
# 1                        18.0              59.924729               10.724579
# 2                        12.0              59.912779               10.751116
# 3                        15.0              59.914990               10.773942
# 4                        30.0              59.915620               10.762248
# ...                       ...                    ...                     ...
# 242753                   27.0              59.929829               10.713032
# 242754                   15.0              59.920187               10.717955
# 242755                   48.0              59.910287               10.750012
# 242756                   48.0              59.910287               10.750012
# 242757                   15.0              59.927141               10.730917
#
#         distance_to_oslo_center_start in_service_end  \
# 0                            2.579575           True
# 1                            1.796597           True
# 2                            0.279750           True
# 3                            1.572725           True
# 4                            0.956887           True
# ...                               ...            ...
# 242753                       2.650263           True
# 242754                       1.775960           True
# 242755                       0.345761           True
# 242756                       0.345761           True
# 242757                       1.815077           True
#
#                           title_end  number_of_locks_end  center.latitude_end  \
# 0                         Tinghuset                 10.0            59.915640
# 1                   GrÃ¸nlands torg                 15.0            59.912504
# 2            Arkitekt Rivertz Plass                 30.0            59.934934
# 3                  Vaterlandsparken                 42.0            59.913409
# 4                  Vaterlandsparken                 42.0            59.913409
# ...                             ...                  ...                  ...
# 242753  VÃ¥r Frelsers gravlund sÃ¸r                 18.0            59.919530
# 242754                   Tjuvholmen                 30.0            59.909494
# 242755        Helga Helgesens plass                 25.0            59.912071
# 242756        Munkegata trikkestopp                 24.0            59.908184
# 242757              Valkyrieplassen                 12.0            59.928202
#
#         center.longitude_end  distance_to_oslo_center_end
# 0                  10.740921                     0.436133
# 1                  10.762236                     0.899754
# 2                  10.749475                     2.479451
# 3                  10.757370                     0.633157
# 4                  10.757370                     0.633157
# ...                      ...                          ...
# 242753             10.743836                     0.769874
# 242754             10.722502                     1.362960
# 242755             10.766201                     1.122704
# 242756             10.767799                     1.309760
# 242757             10.718301                     2.317656
#
# [242747 rows x 16 columns]

# %% [markdown]
# ## What are the busiest stations?

# %% [markdown]
# Let's first find the busiest station:

# %%
busy_station = merged_bike_stats2['Start station'].value_counts()[:5]
busy_station.plot.bar()
# Out:
# <Axes: xlabel='Start station'>

# %%
stations.loc[busy_station.index]
# Out:
#                in_service                      title  number_of_locks  \
# Start station
# 233                  True  Alexander Kiellands Plass               25
# 267                  True            Bislett Stadion               24
# 222                  True            Olaf Ryes plass               35
# 294                  True                   Torggata               30
# 181                  True                Kirkeristen               24
#
#                center.latitude  center.longitude  distance_to_oslo_center
# Start station
# 233                  59.928050         10.751203                 1.730373
# 267                  59.925480         10.731318                 1.642612
# 222                  59.922414         10.758127                 1.271247
# 294                  59.915936         10.751573                 0.471746
# 181                  59.913015         10.746714                 0.048973

# %% [markdown]
# ### What is the usage pattern of the busiest station?

# %% [markdown]
# Filter out all trips starting from the bussiest station

# %%
ak_plass_stats = merged_bike_stats[
    merged_bike_stats["Start station"] == busy_station.index[0]
]
ak_plass_stats.head()
# Out:
#      Start station                Start time  End station  \
# 19             233 2016-10-01 04:17:36+00:00          200
# 70             233 2016-10-01 04:56:24+00:00          196
# 99             233 2016-10-01 05:13:05+00:00          298
# 111            233 2016-10-01 05:16:18+00:00          297
# 183            233 2016-10-01 05:44:59+00:00          192
#
#                      End time in_service                      title  \
# 19  2016-10-01 04:31:11+00:00       True  Alexander Kiellands Plass
# 70  2016-10-01 04:58:14+00:00       True  Alexander Kiellands Plass
# 99  2016-10-01 05:30:54+00:00       True  Alexander Kiellands Plass
# 111 2016-10-01 05:26:09+00:00       True  Alexander Kiellands Plass
# 183 2016-10-01 05:52:18+00:00       True  Alexander Kiellands Plass
#
#      number_of_locks  center.latitude  center.longitude  \
# 19              25.0         59.92805         10.751203
# 70              25.0         59.92805         10.751203
# 99              25.0         59.92805         10.751203
# 111             25.0         59.92805         10.751203
# 183             25.0         59.92805         10.751203
#
#      distance_to_oslo_center
# 19                  1.730373
# 70                  1.730373
# 99                  1.730373
# 111                 1.730373
# 183                 1.730373

# %% [markdown]
# Plot the results:

# %%
resampled_trips = pd.DataFrame({"Counter": 1}, index=ak_plass_stats["Start time"])
resampled_trips.head()
# Out:
#                            Counter
# Start time
# 2016-10-01 04:17:36+00:00        1
# 2016-10-01 04:56:24+00:00        1
# 2016-10-01 05:13:05+00:00        1
# 2016-10-01 05:16:18+00:00        1
# 2016-10-01 05:44:59+00:00        1

# %%
# resample every 30 minutes and sum results
resampled_trips = resampled_trips.resample("30T").sum()
resampled_trips.head()
# Out:
# C:\Users\58263\AppData\Local\Temp\ipykernel_18792\4029526604.py:2: FutureWarning: 'T' is deprecated and will be removed in a future version, please use 'min' instead.
#   resampled_trips = resampled_trips.resample("30T").sum()
#                            Counter
# Start time
# 2016-10-01 04:00:00+00:00        1
# 2016-10-01 04:30:00+00:00        1
# 2016-10-01 05:00:00+00:00        2
# 2016-10-01 05:30:00+00:00        1
# 2016-10-01 06:00:00+00:00        1

# %% [markdown]
# # Public data APIs
#
# How do we access amazing data? The answer is data APIs.
#
# What is an API?

# %% [markdown]
# ## What is an API?
# API stands for Application Programming Interface and it serves as a data transmitter between two different pieces of software. The term has historically been used to describe any sort of connectivity interface to an application.
#
# Today, the term API typically takes an additional meaning:
# - Modern APIs adhere to certain standards (typically HTTP and REST)
# - They are treated like products
# - They often adhere to high security standards

# %% [markdown]
# ## Types of APIs
#
# ### By availability
# - **Open and public APIs** are available to everyone. Open APIs will be completely open, in the sense that they will provide access to the complete architecture and all features of their code.  Public APIs, contrarily, will provide restricted access to the codes and datasets.
#
# <img src="figs/open-apis.png" width=400 height=400 />
#
# - **Internal APIs** are used in-house by developers.
#
# - **Partner APIs** are a form of open API where access is granted under certain conditions determined by the publisher.

# %% [markdown]
# ### By structure
# APIs also differ in architecture. The most popular API architectures are:
# - **JSON-RPC and XML-RPC**
# RPC stands for Remote Procedure Call and is a protocol for data transmission in JSON or XML format.
# - **REST**
# REST stands for representational state transfer. It's a software architectural style that provides a set of recommendations for web development.
# - **SOAP** stands for simple object access protocol and is a definition of API protocols and standards.

# %% [markdown]
# ## Accessing a Public Data API with Python
#
# In order to retrieve data from an API we will combine the ``requests`` library and the ``JSON`` library.
#
# When we want to receive data from the API we first make a *request*.
#
# To do so in python, we need to install the ``requests`` library.
#
# Open the virtual environment you are using for this course and run

# %%
! pip install requests
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: requests in c:\users\58263\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\58263\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\58263\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\58263\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\58263\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests) (2024.7.4)

# %% [markdown]
# If you are using conda you can write ``conda install requests``.
#
# As soon as we have installed it we can import it

# %%
import requests

# %% [markdown]
# ### Example: NASA's APOD API
#
# Let us test out [NASA's open API](https://api.nasa.gov/):

# %%
demo_key = "DEMO_KEY"

url = "https://api.nasa.gov/planetary/apod?api_key=" + demo_key

response = requests.get(url)
response.json()
# Out:
# {'copyright': 'Adam Block',
#  'date': '2024-10-18',
#  'explanation': "On October 14 it was hard to capture a full view of Comet C/2023 A3 Tsuchinshan-ATLAS. Taken after the comet's closest approach to our fair planet, this evening skyview almost does though. With two telephoto frames combined, the image stretches about 26 degrees across the sky from top to bottom, looking west from Gates Pass, Tucson, Arizona. Comet watchers that night could even identify globular star cluster M5 and the faint apparition of periodic comet 13P Olbers near the long the path of Tsuchinshan-ATLAS's whitish dust tail above the bright comet's coma. Due to perspective as the Earth is crossing the comet's orbital plane, Tsuchinshan-ATLAS also has a pronounced antitail. The antitail is composed of dust previously released and fanning out away from the Sun along the comet's orbit, visible as a needle-like extension below the bright coma toward the rugged western horizon.   Growing Gallery: Comet Tsuchinshan-ATLAS in 2024",
#  'hdurl': 'https://apod.nasa.gov/apod/image/2410/a3_20241014_s.jpg',
#  'media_type': 'image',
#  'service_version': 'v1',
#  'title': 'Most of Comet Tsuchinshan-ATLAS',
#  'url': 'https://apod.nasa.gov/apod/image/2410/a3_20241014_s1200.jpg'}

# %%
import json
data = response.json()
from IPython.display import Image
from IPython.core.display import HTML 

print(response.json()['explanation'])
Image(url=data['url'], width=600)
# Out:
# On October 14 it was hard to capture a full view of Comet C/2023 A3 Tsuchinshan-ATLAS. Taken after the comet's closest approach to our fair planet, this evening skyview almost does though. With two telephoto frames combined, the image stretches about 26 degrees across the sky from top to bottom, looking west from Gates Pass, Tucson, Arizona. Comet watchers that night could even identify globular star cluster M5 and the faint apparition of periodic comet 13P Olbers near the long the path of Tsuchinshan-ATLAS's whitish dust tail above the bright comet's coma. Due to perspective as the Earth is crossing the comet's orbital plane, Tsuchinshan-ATLAS also has a pronounced antitail. The antitail is composed of dust previously released and fanning out away from the Sun along the comet's orbit, visible as a needle-like extension below the bright coma toward the rugged western horizon.   Growing Gallery: Comet Tsuchinshan-ATLAS in 2024
# <img src="https://apod.nasa.gov/apod/image/2410/a3_20241014_s1200.jpg" width="600"/>

# %% [markdown]
# ## Key concepts:
#
# **Get and post**
#
# The two most common requests we make are ``get`` and ``post``:
# - ``Get`` is used for viewing (without changing)
# - ``Post`` is used for viewing and possibly changing
#
# **Response codes**
#
# We can check the response code to see if our request was successfull.

# %%
if response.status_code == 200:
    print('Request succeeded!')
else: 
    print(f'Uhoh, we got response code {response.status_code}...')
# Out:
# Request succeeded!

# %% [markdown]
# Here are some common status codes:
#
# (defined by HTTP)
#
# | Code | Status | Description |
# | --- | --- | --- |
# | 200 | OK | The request was successfully completed   |
# | 400 | Bad request| The request was invalid. |
# | 401 | Unauthorized | The request did not include an authentication token or the authentication token was expired. |
# | 403 | Forbidden | The client did not have permission to access the requested resource. |
# | 404 | Not Found | The requested resource was not found. |
# | 405 | Not Allowed | The client did not have permission to access the requested resource. |
# | 500 | Internal Server Error | The request was not completed due to an internal error on the server side. |
# | 503 | Service unavailable | The server was unavailable. |
#
# **Headers**
#
# We can communicate metadata (like who we are) to the API by means of a *header*.
#
# The API also communicates back to us with a header:

# %%
response.headers
# Out:
# {'Date': 'Fri, 20 Sep 2024 10:16:02 GMT', 'Content-Type': 'application/json', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Access-Control-Allow-Origin': '*', 'Access-Control-Expose-Headers': 'X-RateLimit-Limit, X-RateLimit-Remaining', 'Age': '2', 'Content-Encoding': 'gzip', 'Strict-Transport-Security': 'max-age=31536000; includeSubDomains; preload', 'Vary': 'Accept-Encoding', 'Via': 'https/1.1 api-umbrella (ApacheTrafficServer [cMsSf ])', 'X-Api-Umbrella-Request-Id': 'ci1rn7d6mi68dcer75q0', 'X-Cache': 'MISS', 'X-Content-Type-Options': 'nosniff', 'X-Ratelimit-Limit': '40', 'X-Ratelimit-Remaining': '38', 'X-Vcap-Request-Id': '620dd346-b10b-47e9-4830-66b5d0e1d151', 'X-Xss-Protection': '1; mode=block', 'X-Frame-Options': 'DENY'}

# %% [markdown]
# **Etiquette**
#
# When you access a public data API you are expected to follow the playing rules of the API. Therefore you should always start by checking the documentation on the website for the API.
#
# <div>
# <img src="figs/rtfm.png" width="250"/>
# </div>
#
# In programming this is often referred to as RTFM (read the freaking manual).
#
# [xkcd: RTFM](https://xkcd.com/293/)

# %%
requests.get?
# Out:
# Signature: requests.get(url, params=None, **kwargs)
# Docstring:
# Sends a GET request.
#
# :param url: URL for the new :class:`Request` object.
# :param params: (optional) Dictionary, list of tuples or bytes to send
#     in the query string for the :class:`Request`.
# :param \*\*kwargs: Optional arguments that ``request`` takes.
# :return: :class:`Response <Response>` object
# :rtype: requests.Response
# File:      c:\users\58263\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages\requests\api.py
# Type:      function

# %% [markdown]
# The actual data typically gets returned in a ``JSON``, ``XML`` or ``CSV file``.
#
#
# ### CSV
#
# A Comma-Separated Values file is a delimited text file that uses a comma to separate values. It typically stores *tabular data*.
#
# <div>
# <img src="figs/covid-nums.png" width="300"/>
# </div>
#
# *Example*: All tables on statistics from Norway at [SSB](https://www.ssb.no/) can be downloaded as a .csv file.
#
#
#
# ### JSON
# JSON is the most common way of sending data back and forth in APIs.
#
# A JavaScript Object Notation (JSON) file encodes *data structures* so that they are easy to read for machines and somewhat easy to read for humans.
#
# JSON is a text file or string that follows the JavaScript object syntax. Most programming languages will have the ability to read (parse) and generate JSON files.
#
# The ``json`` library in Python has two main functions:
# - `json.dumps()` Takes in a python object and converts it (dumps it) to a string
# - `json.loads()` Takes in a JSON string and converts it (loads it) to a Python object.
#
# which will convert from/to the following formats
#
# | JSON | Python |
# | --- | --- |
# | object | dict |
# | array  | list |
# | string | str  |
# | number (int) |  int |
# | number (real) | float |
# | true | True |
# | false | False |
# | null | None |
#
#
# Let's look at what NASA gave us

# %%
import json

# Load data using response.json 
response.json?
# Out:
# Signature: response.json(**kwargs)
# Docstring:
# Returns the json-encoded content of a response, if any.
#
# :param \*\*kwargs: Optional arguments that ``json.loads`` takes.
# :raises requests.exceptions.JSONDecodeError: If the response body does not
#     contain valid json.
# File:      c:\users\58263\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages\requests\models.py
# Type:      method

# %%
data = response.json()

print('Response.json is a ' + str(type(data)))
print('Printing it yields: ')

response.json()
# Out:
# Response.json is a <class 'dict'>
# Printing it yields:
# {'copyright': 'Petr Horálek',
#  'date': '2024-09-20',
#  'explanation': "For northern hemisphere dwellers, September's Full Moon was the Harvest Moon. On September 17/18 the sunlit lunar nearside passed into shadow, just grazing Earth's umbra, the planet's dark, central shadow cone, in a partial lunar eclipse. Over the two and half hours before dawn a camera fixed to a tripod was used to record this series of exposures as the eclipsed Harvest Moon set behind Spiš Castle in the hazy morning sky over eastern Slovakia. Famed in festival, story, and song, Harvest Moon is just the traditional name of the full moon nearest the autumnal equinox.  According to lore the name is a fitting one. Despite the diminishing daylight hours as the growing season drew to a close, farmers could harvest crops by the light of a full moon shining on from dusk to dawn. This September's Harvest Moon was also known to some as a supermoon, a term becoming a traditional name for a full moon near perigee.",
#  'hdurl': 'https://apod.nasa.gov/apod/image/2409/2024_09_18_ZM_Spis_50mm-Pano_Postupka_1500px.png',
#  'media_type': 'image',
#  'service_version': 'v1',
#  'title': 'A Hazy Harvest Moon',
#  'url': 'https://apod.nasa.gov/apod/image/2409/2024_09_18_ZM_Spis_50mm-Pano_Postupka_1024c.png'}

# %% [markdown]
# ## Exercise
#
# 1. Make a get request and parse the data from Kanye Rest API:

# %%
url = 'https://api.kanye.rest/'

r = requests.get(url)
data = r.json()
data
# Out:
# {'quote': 'I hear people say this person is cool and this person is not cool. People are cool. Man has never invented anything as awesome as a an actual person but sometimes we value the objects we create over life itself'}

# %% [markdown]
#  ## Parameters to an API
#  Website links are often very long. It can be difficult to hardcode the entire path of a website if we want to scrape different pages efficiently.
#
#  We can pass parameters to the get request to easier

# %%
demo_key = "DEMO_KEY"


parameters = {"api_key": demo_key,
              "date": "2024-10-17"}

url = "https://api.nasa.gov/planetary/apod"

response = requests.get(url, params=parameters)
data = response.json()
from IPython.display import Image
from IPython.core.display import HTML 

print(response.json()['explanation'])
Image(url=data['url'], width=600)
# Out:
# NASA's Europa Clipper is now headed toward an ocean world beyond Earth. The large spacecraft is tucked into the payload fairing atop the Falcon Heavy rocket in this photo, taken at Kennedy Space Center the day before the mission's successful October 14 launch. Europa Clipper's interplanetary voyage will first take it to Mars, then back to Earth, and then on to Jupiter on gravity assist trajectories that will allow it to enter orbit around Jupiter in April 2030. Once orbiting Jupiter, the spacecraft will fly past Europa 49 times, exploring a Jovian moon with a global subsurface ocean that may have conditions to support life. Posing in the background next to the floodlit rocket is Comet Tsuchinsan-ATLAS, about a day after the comet's closest approach to Earth. A current darling of evening skies, the naked-eye comet is a visitor from the distant Oort cloud  Growing Gallery: Comet Tsuchinshan-ATLAS in 2024
# <img src="https://apod.nasa.gov/apod/image/2410/EuropaComet_cooper3.jpg" width="600"/>

# %% [markdown]
# ## Exercise
#
# 1. Make a get request from the [NASA Mars Rover API](https://api.nasa.gov/) (https://api.nasa.gov/) to get pictures from Mars.
# 2. Specifiy the camera type in parameters
# 3. Explore the api and create a script that allows you to control the different parameters using variables or command line arguments.

# %%
# Get satellite image from Houston
parameters = { 
    'sol': 100,
    'api_key': "DEMO_KEY",
    'page' : 1,
}

url = 'https://api.nasa.gov/mars-photos/api/v1/rovers/curiosity/photos'
r = requests.get( url, parameters)
r_json = r.json()
r_json
# Out:
# {'photos': [{'id': 669,
#    'sol': 100,
#    'camera': {'id': 20,
#     'name': 'FHAZ',
#     'rover_id': 5,
#     'full_name': 'Front Hazard Avoidance Camera'},
#    'img_src': 'http://mars.jpl.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/00100/opgs/edr/fcam/FRA_406374643EDR_F0050178FHAZ00301M_.JPG',
#    'earth_date': '2012-11-16',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active',
#     'max_sol': 4102,
#     'max_date': '2024-02-19',
#     'total_photos': 695670,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'MAST', 'full_name': 'Mast Camera'},
#      {'name': 'CHEMCAM', 'full_name': 'Chemistry and Camera Complex'},
#      {'name': 'MAHLI', 'full_name': 'Mars Hand Lens Imager'},
#      {'name': 'MARDI', 'full_name': 'Mars Descent Imager'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 9487,
#    'sol': 100,
#    'camera': {'id': 20,
#     'name': 'FHAZ',
#     'rover_id': 5,
#     'full_name': 'Front Hazard Avoidance Camera'},
#    'img_src': 'http://mars.jpl.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/00100/opgs/edr/fcam/FLA_406377515EDR_F0050178FHAZ00302M_.JPG',
#    'earth_date': '2012-11-16',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active',
#     'max_sol': 4102,
#     'max_date': '2024-02-19',
#     'total_photos': 695670,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'MAST', 'full_name': 'Mast Camera'},
#      {'name': 'CHEMCAM', 'full_name': 'Chemistry and Camera Complex'},
#      {'name': 'MAHLI', 'full_name': 'Mars Hand Lens Imager'},
#      {'name': 'MARDI', 'full_name': 'Mars Descent Imager'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 9488,
#    'sol': 100,
#    'camera': {'id': 20,
#     'name': 'FHAZ',
#     'rover_id': 5,
#     'full_name': 'Front Hazard Avoidance Camera'},
#    'img_src': 'http://mars.jpl.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/00100/opgs/edr/fcam/FRA_406377515EDR_F0050178FHAZ00302M_.JPG',
#    'earth_date': '2012-11-16',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active',
#     'max_sol': 4102,
#     'max_date': '2024-02-19',
#     'total_photos': 695670,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'MAST', 'full_name': 'Mast Camera'},
#      {'name': 'CHEMCAM', 'full_name': 'Chemistry and Camera Complex'},
#      {'name': 'MAHLI', 'full_name': 'Mars Hand Lens Imager'},
#      {'name': 'MARDI', 'full_name': 'Mars Descent Imager'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 9489,
#    'sol': 100,
#    'camera': {'id': 20,
#     'name': 'FHAZ',
#     'rover_id': 5,
#     'full_name': 'Front Hazard Avoidance Camera'},
#    'img_src': 'http://mars.jpl.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/00100/opgs/edr/fcam/FLA_406374643EDR_F0050178FHAZ00301M_.JPG',
#    'earth_date': '2012-11-16',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active',
#     'max_sol': 4102,
#     'max_date': '2024-02-19',
#     'total_photos': 695670,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'MAST', 'full_name': 'Mast Camera'},
#      {'name': 'CHEMCAM', 'full_name': 'Chemistry and Camera Complex'},
#      {'name': 'MAHLI', 'full_name': 'Mars Hand Lens Imager'},
#      {'name': 'MARDI', 'full_name': 'Mars Descent Imager'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 1391,
#    'sol': 100,
#    'camera': {'id': 21,
#     'name': 'RHAZ',
#     'rover_id': 5,
#     'full_name': 'Rear Hazard Avoidance Camera'},
#    'img_src': 'http://mars.jpl.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/00100/opgs/edr/rcam/RRA_406377548EDR_F0050178RHAZ00311M_.JPG',
#    'earth_date': '2012-11-16',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active',
#     'max_sol': 4102,
#     'max_date': '2024-02-19',
#     'total_photos': 695670,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'MAST', 'full_name': 'Mast Camera'},
#      {'name': 'CHEMCAM', 'full_name': 'Chemistry and Camera Complex'},
#      {'name': 'MAHLI', 'full_name': 'Mars Hand Lens Imager'},
#      {'name': 'MARDI', 'full_name': 'Mars Descent Imager'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 12606,
#    'sol': 100,
#    'camera': {'id': 21,
#     'name': 'RHAZ',
#     'rover_id': 5,
#     'full_name': 'Rear Hazard Avoidance Camera'},
#    'img_src': 'http://mars.jpl.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/00100/opgs/edr/rcam/RLA_406377548EDR_F0050178RHAZ00311M_.JPG',
#    'earth_date': '2012-11-16',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active',
#     'max_sol': 4102,
#     'max_date': '2024-02-19',
#     'total_photos': 695670,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'MAST', 'full_name': 'Mast Camera'},
#      {'name': 'CHEMCAM', 'full_name': 'Chemistry and Camera Complex'},
#      {'name': 'MAHLI', 'full_name': 'Mars Hand Lens Imager'},
#      {'name': 'MARDI', 'full_name': 'Mars Descent Imager'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 4405,
#    'sol': 100,
#    'camera': {'id': 22,
#     'name': 'MAST',
#     'rover_id': 5,
#     'full_name': 'Mast Camera'},
#    'img_src': 'http://mars.jpl.nasa.gov/msl-raw-images/msss/00100/mcam/0100MR0006610000104362I01_DXXX.jpg',
#    'earth_date': '2012-11-16',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active',
#     'max_sol': 4102,
#     'max_date': '2024-02-19',
#     'total_photos': 695670,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'MAST', 'full_name': 'Mast Camera'},
#      {'name': 'CHEMCAM', 'full_name': 'Chemistry and Camera Complex'},
#      {'name': 'MAHLI', 'full_name': 'Mars Hand Lens Imager'},
#      {'name': 'MARDI', 'full_name': 'Mars Descent Imager'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 494288,
#    'sol': 100,
#    'camera': {'id': 22,
#     'name': 'MAST',
#     'rover_id': 5,
#     'full_name': 'Mast Camera'},
#    'img_src': 'http://mars.jpl.nasa.gov/msl-raw-images/msss/00100/mcam/0100ML0004900050102961C00_DXXX.jpg',
#    'earth_date': '2012-11-16',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active',
#     'max_sol': 4102,
#     'max_date': '2024-02-19',
#     'total_photos': 695670,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'MAST', 'full_name': 'Mast Camera'},
#      {'name': 'CHEMCAM', 'full_name': 'Chemistry and Camera Complex'},
#      {'name': 'MAHLI', 'full_name': 'Mars Hand Lens Imager'},
#      {'name': 'MARDI', 'full_name': 'Mars Descent Imager'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 494289,
#    'sol': 100,
#    'camera': {'id': 22,
#     'name': 'MAST',
#     'rover_id': 5,
#     'full_name': 'Mast Camera'},
#    'img_src': 'http://mars.jpl.nasa.gov/msl-raw-images/msss/00100/mcam/0100ML0004900050102961E01_DXXX.jpg',
#    'earth_date': '2012-11-16',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active',
#     'max_sol': 4102,
#     'max_date': '2024-02-19',
#     'total_photos': 695670,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'MAST', 'full_name': 'Mast Camera'},
#      {'name': 'CHEMCAM', 'full_name': 'Chemistry and Camera Complex'},
#      {'name': 'MAHLI', 'full_name': 'Mars Hand Lens Imager'},
#      {'name': 'MARDI', 'full_name': 'Mars Descent Imager'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 494290,
#    'sol': 100,
#    'camera': {'id': 22,
#     'name': 'MAST',
#     'rover_id': 5,
#     'full_name': 'Mast Camera'},
#    'img_src': 'http://mars.jpl.nasa.gov/msl-raw-images/msss/00100/mcam/0100MR0004900040104454E01_DXXX.jpg',
#    'earth_date': '2012-11-16',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active',
#     'max_sol': 4102,
#     'max_date': '2024-02-19',
#     'total_photos': 695670,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'MAST', 'full_name': 'Mast Camera'},
#      {'name': 'CHEMCAM', 'full_name': 'Chemistry and Camera Complex'},
#      {'name': 'MAHLI', 'full_name': 'Mars Hand Lens Imager'},
#      {'name': 'MARDI', 'full_name': 'Mars Descent Imager'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 494291,
#    'sol': 100,
#    'camera': {'id': 22,
#     'name': 'MAST',
#     'rover_id': 5,
#     'full_name': 'Mast Camera'},
#    'img_src': 'http://mars.jpl.nasa.gov/msl-raw-images/msss/00100/mcam/0100MR0004900040104454C00_DXXX.jpg',
#    'earth_date': '2012-11-16',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active',
#     'max_sol': 4102,
#     'max_date': '2024-02-19',
#     'total_photos': 695670,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'MAST', 'full_name': 'Mast Camera'},
#      {'name': 'CHEMCAM', 'full_name': 'Chemistry and Camera Complex'},
#      {'name': 'MAHLI', 'full_name': 'Mars Hand Lens Imager'},
#      {'name': 'MARDI', 'full_name': 'Mars Descent Imager'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 494292,
#    'sol': 100,
#    'camera': {'id': 22,
#     'name': 'MAST',
#     'rover_id': 5,
#     'full_name': 'Mast Camera'},
#    'img_src': 'http://mars.jpl.nasa.gov/msl-raw-images/msss/00100/mcam/0100MR0006680130104476D01_DXXX.jpg',
#    'earth_date': '2012-11-16',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active',
#     'max_sol': 4102,
#     'max_date': '2024-02-19',
#     'total_photos': 695670,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'MAST', 'full_name': 'Mast Camera'},
#      {'name': 'CHEMCAM', 'full_name': 'Chemistry and Camera Complex'},
#      {'name': 'MAHLI', 'full_name': 'Mars Hand Lens Imager'},
#      {'name': 'MARDI', 'full_name': 'Mars Descent Imager'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 494293,
#    'sol': 100,
#    'camera': {'id': 22,
#     'name': 'MAST',
#     'rover_id': 5,
#     'full_name': 'Mast Camera'},
#    'img_src': 'http://mars.jpl.nasa.gov/msl-raw-images/msss/00100/mcam/0100MR0006680120104475D01_DXXX.jpg',
#    'earth_date': '2012-11-16',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active',
#     'max_sol': 4102,
#     'max_date': '2024-02-19',
#     'total_photos': 695670,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'MAST', 'full_name': 'Mast Camera'},
#      {'name': 'CHEMCAM', 'full_name': 'Chemistry and Camera Complex'},
#      {'name': 'MAHLI', 'full_name': 'Mars Hand Lens Imager'},
#      {'name': 'MARDI', 'full_name': 'Mars Descent Imager'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 494294,
#    'sol': 100,
#    'camera': {'id': 22,
#     'name': 'MAST',
#     'rover_id': 5,
#     'full_name': 'Mast Camera'},
#    'img_src': 'http://mars.jpl.nasa.gov/msl-raw-images/msss/00100/mcam/0100MR0006680110104474D01_DXXX.jpg',
#    'earth_date': '2012-11-16',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active',
#     'max_sol': 4102,
#     'max_date': '2024-02-19',
#     'total_photos': 695670,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'MAST', 'full_name': 'Mast Camera'},
#      {'name': 'CHEMCAM', 'full_name': 'Chemistry and Camera Complex'},
#      {'name': 'MAHLI', 'full_name': 'Mars Hand Lens Imager'},
#      {'name': 'MARDI', 'full_name': 'Mars Descent Imager'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 494295,
#    'sol': 100,
#    'camera': {'id': 22,
#     'name': 'MAST',
#     'rover_id': 5,
#     'full_name': 'Mast Camera'},
#    'img_src': 'http://mars.jpl.nasa.gov/msl-raw-images/msss/00100/mcam/0100MR0006680100104473D01_DXXX.jpg',
#    'earth_date': '2012-11-16',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active',
#     'max_sol': 4102,
#     'max_date': '2024-02-19',
#     'total_photos': 695670,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'MAST', 'full_name': 'Mast Camera'},
#      {'name': 'CHEMCAM', 'full_name': 'Chemistry and Camera Complex'},
#      {'name': 'MAHLI', 'full_name': 'Mars Hand Lens Imager'},
#      {'name': 'MARDI', 'full_name': 'Mars Descent Imager'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 494296,
#    'sol': 100,
#    'camera': {'id': 22,
#     'name': 'MAST',
#     'rover_id': 5,
#     'full_name': 'Mast Camera'},
#    'img_src': 'http://mars.jpl.nasa.gov/msl-raw-images/msss/00100/mcam/0100MR0006680090104472D01_DXXX.jpg',
#    'earth_date': '2012-11-16',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active',
#     'max_sol': 4102,
#     'max_date': '2024-02-19',
#     'total_photos': 695670,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'MAST', 'full_name': 'Mast Camera'},
#      {'name': 'CHEMCAM', 'full_name': 'Chemistry and Camera Complex'},
#      {'name': 'MAHLI', 'full_name': 'Mars Hand Lens Imager'},
#      {'name': 'MARDI', 'full_name': 'Mars Descent Imager'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 494297,
#    'sol': 100,
#    'camera': {'id': 22,
#     'name': 'MAST',
#     'rover_id': 5,
#     'full_name': 'Mast Camera'},
#    'img_src': 'http://mars.jpl.nasa.gov/msl-raw-images/msss/00100/mcam/0100MR0006680080104471D01_DXXX.jpg',
#    'earth_date': '2012-11-16',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active',
#     'max_sol': 4102,
#     'max_date': '2024-02-19',
#     'total_photos': 695670,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'MAST', 'full_name': 'Mast Camera'},
#      {'name': 'CHEMCAM', 'full_name': 'Chemistry and Camera Complex'},
#      {'name': 'MAHLI', 'full_name': 'Mars Hand Lens Imager'},
#      {'name': 'MARDI', 'full_name': 'Mars Descent Imager'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 494298,
#    'sol': 100,
#    'camera': {'id': 22,
#     'name': 'MAST',
#     'rover_id': 5,
#     'full_name': 'Mast Camera'},
#    'img_src': 'http://mars.jpl.nasa.gov/msl-raw-images/msss/00100/mcam/0100MR0006680070104470E01_DXXX.jpg',
#    'earth_date': '2012-11-16',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active',
#     'max_sol': 4102,
#     'max_date': '2024-02-19',
#     'total_photos': 695670,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'MAST', 'full_name': 'Mast Camera'},
#      {'name': 'CHEMCAM', 'full_name': 'Chemistry and Camera Complex'},
#      {'name': 'MAHLI', 'full_name': 'Mars Hand Lens Imager'},
#      {'name': 'MARDI', 'full_name': 'Mars Descent Imager'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 494299,
#    'sol': 100,
#    'camera': {'id': 22,
#     'name': 'MAST',
#     'rover_id': 5,
#     'full_name': 'Mast Camera'},
#    'img_src': 'http://mars.jpl.nasa.gov/msl-raw-images/msss/00100/mcam/0100ML0006680060102985D01_DXXX.jpg',
#    'earth_date': '2012-11-16',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active',
#     'max_sol': 4102,
#     'max_date': '2024-02-19',
#     'total_photos': 695670,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'MAST', 'full_name': 'Mast Camera'},
#      {'name': 'CHEMCAM', 'full_name': 'Chemistry and Camera Complex'},
#      {'name': 'MAHLI', 'full_name': 'Mars Hand Lens Imager'},
#      {'name': 'MARDI', 'full_name': 'Mars Descent Imager'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 494300,
#    'sol': 100,
#    'camera': {'id': 22,
#     'name': 'MAST',
#     'rover_id': 5,
#     'full_name': 'Mast Camera'},
#    'img_src': 'http://mars.jpl.nasa.gov/msl-raw-images/msss/00100/mcam/0100ML0006680050102984D01_DXXX.jpg',
#    'earth_date': '2012-11-16',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active',
#     'max_sol': 4102,
#     'max_date': '2024-02-19',
#     'total_photos': 695670,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'MAST', 'full_name': 'Mast Camera'},
#      {'name': 'CHEMCAM', 'full_name': 'Chemistry and Camera Complex'},
#      {'name': 'MAHLI', 'full_name': 'Mars Hand Lens Imager'},
#      {'name': 'MARDI', 'full_name': 'Mars Descent Imager'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 494301,
#    'sol': 100,
#    'camera': {'id': 22,
#     'name': 'MAST',
#     'rover_id': 5,
#     'full_name': 'Mast Camera'},
#    'img_src': 'http://mars.jpl.nasa.gov/msl-raw-images/msss/00100/mcam/0100ML0006680040102983D01_DXXX.jpg',
#    'earth_date': '2012-11-16',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active',
#     'max_sol': 4102,
#     'max_date': '2024-02-19',
#     'total_photos': 695670,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'MAST', 'full_name': 'Mast Camera'},
#      {'name': 'CHEMCAM', 'full_name': 'Chemistry and Camera Complex'},
#      {'name': 'MAHLI', 'full_name': 'Mars Hand Lens Imager'},
#      {'name': 'MARDI', 'full_name': 'Mars Descent Imager'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 494302,
#    'sol': 100,
#    'camera': {'id': 22,
#     'name': 'MAST',
#     'rover_id': 5,
#     'full_name': 'Mast Camera'},
#    'img_src': 'http://mars.jpl.nasa.gov/msl-raw-images/msss/00100/mcam/0100ML0006680030102982D01_DXXX.jpg',
#    'earth_date': '2012-11-16',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active',
#     'max_sol': 4102,
#     'max_date': '2024-02-19',
#     'total_photos': 695670,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'MAST', 'full_name': 'Mast Camera'},
#      {'name': 'CHEMCAM', 'full_name': 'Chemistry and Camera Complex'},
#      {'name': 'MAHLI', 'full_name': 'Mars Hand Lens Imager'},
#      {'name': 'MARDI', 'full_name': 'Mars Descent Imager'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 494303,
#    'sol': 100,
#    'camera': {'id': 22,
#     'name': 'MAST',
#     'rover_id': 5,
#     'full_name': 'Mast Camera'},
#    'img_src': 'http://mars.jpl.nasa.gov/msl-raw-images/msss/00100/mcam/0100ML0006680020102981D01_DXXX.jpg',
#    'earth_date': '2012-11-16',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active',
#     'max_sol': 4102,
#     'max_date': '2024-02-19',
#     'total_photos': 695670,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'MAST', 'full_name': 'Mast Camera'},
#      {'name': 'CHEMCAM', 'full_name': 'Chemistry and Camera Complex'},
#      {'name': 'MAHLI', 'full_name': 'Mars Hand Lens Imager'},
#      {'name': 'MARDI', 'full_name': 'Mars Descent Imager'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 494304,
#    'sol': 100,
#    'camera': {'id': 22,
#     'name': 'MAST',
#     'rover_id': 5,
#     'full_name': 'Mast Camera'},
#    'img_src': 'http://mars.jpl.nasa.gov/msl-raw-images/msss/00100/mcam/0100ML0006680010102980D01_DXXX.jpg',
#    'earth_date': '2012-11-16',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active',
#     'max_sol': 4102,
#     'max_date': '2024-02-19',
#     'total_photos': 695670,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'MAST', 'full_name': 'Mast Camera'},
#      {'name': 'CHEMCAM', 'full_name': 'Chemistry and Camera Complex'},
#      {'name': 'MAHLI', 'full_name': 'Mars Hand Lens Imager'},
#      {'name': 'MARDI', 'full_name': 'Mars Descent Imager'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 494305,
#    'sol': 100,
#    'camera': {'id': 22,
#     'name': 'MAST',
#     'rover_id': 5,
#     'full_name': 'Mast Camera'},
#    'img_src': 'http://mars.jpl.nasa.gov/msl-raw-images/msss/00100/mcam/0100ML0006680000102979E01_DXXX.jpg',
#    'earth_date': '2012-11-16',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active',
#     'max_sol': 4102,
#     'max_date': '2024-02-19',
#     'total_photos': 695670,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'MAST', 'full_name': 'Mast Camera'},
#      {'name': 'CHEMCAM', 'full_name': 'Chemistry and Camera Complex'},
#      {'name': 'MAHLI', 'full_name': 'Mars Hand Lens Imager'},
#      {'name': 'MARDI', 'full_name': 'Mars Descent Imager'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}}]}

# %%
Image(url=r_json['photos'][0]["img_src"], width=600)
# Out:
# <img src="http://mars.jpl.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/00100/opgs/edr/fcam/FRA_406374643EDR_F0050178FHAZ00301M_.JPG" width="600"/>

# %% [markdown]
# ## https://api.nve.no/doc/magasinstatistikk/
# ## https://biapi.nve.no/nettleiestatistikk/swagger/index.html

# %%
data = requests.get("https://biapi.nve.no/magasinstatistikk/api/Magasinstatistikk/HentOffentligData")
data.json()
# Out:
# [{'dato_Id': '2012-09-02',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 2012,
#   'iso_uke': 35,
#   'fyllingsgrad': 0.9119905,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 8.319808,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.91406196,
#   'endring_fyllingsgrad': -0.0020714402},
#  {'dato_Id': '1997-07-06',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 1997,
#   'iso_uke': 27,
#   'fyllingsgrad': 0.81757194,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 7.4584556,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.7038137,
#   'endring_fyllingsgrad': 0.113758266},
#  {'dato_Id': '2002-07-21',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 2002,
#   'iso_uke': 29,
#   'fyllingsgrad': 0.8566613,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 7.8150563,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.84738106,
#   'endring_fyllingsgrad': 0.009280264},
#  {'dato_Id': '1998-10-04',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 1998,
#   'iso_uke': 40,
#   'fyllingsgrad': 0.9120685,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 8.3205185,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.9256756,
#   'endring_fyllingsgrad': -0.013607085},
#  {'dato_Id': '1998-04-05',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 1998,
#   'iso_uke': 14,
#   'fyllingsgrad': 0.33885214,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 3.0912433,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.36109427,
#   'endring_fyllingsgrad': -0.022242129},
#  {'dato_Id': '1995-04-09',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 1995,
#   'iso_uke': 14,
#   'fyllingsgrad': 0.17750438,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 1.6193175,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.20630443,
#   'endring_fyllingsgrad': -0.028800055},
#  {'dato_Id': '2008-10-19',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 2008,
#   'iso_uke': 42,
#   'fyllingsgrad': 0.8056847,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 7.3500123,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.7936534,
#   'endring_fyllingsgrad': 0.012031257},
#  {'dato_Id': '1999-12-19',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 1999,
#   'iso_uke': 50,
#   'fyllingsgrad': 0.7587317,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 6.9216747,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.7953385,
#   'endring_fyllingsgrad': -0.03660679},
#  {'dato_Id': '2011-09-18',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 2011,
#   'iso_uke': 37,
#   'fyllingsgrad': 0.9156829,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 8.353492,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.88576126,
#   'endring_fyllingsgrad': 0.02992165},
#  {'dato_Id': '2000-08-27',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 2000,
#   'iso_uke': 34,
#   'fyllingsgrad': 0.9508075,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 8.673923,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.95520496,
#   'endring_fyllingsgrad': -0.004397452},
#  {'dato_Id': '2005-11-20',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 2005,
#   'iso_uke': 46,
#   'fyllingsgrad': 0.84576225,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 7.7156277,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.8516954,
#   'endring_fyllingsgrad': -0.0059331656},
#  {'dato_Id': '2005-10-16',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 2005,
#   'iso_uke': 41,
#   'fyllingsgrad': 0.89179003,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 8.135525,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.9059514,
#   'endring_fyllingsgrad': -0.014161348},
#  {'dato_Id': '2006-06-11',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 2006,
#   'iso_uke': 23,
#   'fyllingsgrad': 0.38475266,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 3.5099795,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.34229222,
#   'endring_fyllingsgrad': 0.04246044},
#  {'dato_Id': '2013-11-03',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 2013,
#   'iso_uke': 44,
#   'fyllingsgrad': 0.7541004,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 6.879424,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.75523394,
#   'endring_fyllingsgrad': -0.0011335611},
#  {'dato_Id': '2005-08-28',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 2005,
#   'iso_uke': 34,
#   'fyllingsgrad': 0.9085803,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 8.288697,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.90109617,
#   'endring_fyllingsgrad': 0.007484138},
#  {'dato_Id': '1996-10-13',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 1996,
#   'iso_uke': 41,
#   'fyllingsgrad': 0.7263333,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 6.6261144,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.7054481,
#   'endring_fyllingsgrad': 0.02088523},
#  {'dato_Id': '2011-03-20',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 2011,
#   'iso_uke': 11,
#   'fyllingsgrad': 0.15426442,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 1.4073066,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.17894612,
#   'endring_fyllingsgrad': -0.024681702},
#  {'dato_Id': '2010-12-19',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 2010,
#   'iso_uke': 50,
#   'fyllingsgrad': 0.47871032,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 4.367126,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.5130054,
#   'endring_fyllingsgrad': -0.034295052},
#  {'dato_Id': '2011-01-23',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 2011,
#   'iso_uke': 3,
#   'fyllingsgrad': 0.36001667,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 3.2843206,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.37238574,
#   'endring_fyllingsgrad': -0.0123690665},
#  {'dato_Id': '2009-04-05',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 2009,
#   'iso_uke': 14,
#   'fyllingsgrad': 0.17496505,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 1.596152,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.19197029,
#   'endring_fyllingsgrad': -0.017005235},
#  {'dato_Id': '2008-11-09',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 2008,
#   'iso_uke': 45,
#   'fyllingsgrad': 0.7843712,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 7.1555758,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.79988045,
#   'endring_fyllingsgrad': -0.015509248},
#  {'dato_Id': '2005-07-03',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 2005,
#   'iso_uke': 26,
#   'fyllingsgrad': 0.68327826,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 6.233336,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.611184,
#   'endring_fyllingsgrad': 0.07209426},
#  {'dato_Id': '2003-03-02',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 2003,
#   'iso_uke': 9,
#   'fyllingsgrad': 0.26070032,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 2.3782883,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.29017183,
#   'endring_fyllingsgrad': -0.029471517},
#  {'dato_Id': '2000-03-05',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 2000,
#   'iso_uke': 9,
#   'fyllingsgrad': 0.40104866,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 3.6586428,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.43536583,
#   'endring_fyllingsgrad': -0.034317166},
#  {'dato_Id': '2001-06-10',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 2001,
#   'iso_uke': 23,
#   'fyllingsgrad': 0.41360182,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 3.7731614,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.3627465,
#   'endring_fyllingsgrad': 0.05085531},
#  {'dato_Id': '2007-12-30',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 2007,
#   'iso_uke': 52,
#   'fyllingsgrad': 0.75796455,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 6.9146757,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.7786981,
#   'endring_fyllingsgrad': -0.020733535},
#  {'dato_Id': '2005-01-30',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 2005,
#   'iso_uke': 4,
#   'fyllingsgrad': 0.5529255,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 5.0441685,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.5902696,
#   'endring_fyllingsgrad': -0.037344098},
#  {'dato_Id': '2007-03-11',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 2007,
#   'iso_uke': 10,
#   'fyllingsgrad': 0.34536716,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 3.1506777,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.3801603,
#   'endring_fyllingsgrad': -0.03479314},
#  {'dato_Id': '2002-08-11',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 2002,
#   'iso_uke': 32,
#   'fyllingsgrad': 0.8663997,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 7.9038963,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.87395936,
#   'endring_fyllingsgrad': -0.007559657},
#  {'dato_Id': '2007-01-14',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 2007,
#   'iso_uke': 2,
#   'fyllingsgrad': 0.6222743,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 5.6768155,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.640915,
#   'endring_fyllingsgrad': -0.018640697},
#  {'dato_Id': '2010-06-27',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 2010,
#   'iso_uke': 25,
#   'fyllingsgrad': 0.5823887,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 5.3129516,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.5235373,
#   'endring_fyllingsgrad': 0.05885142},
#  {'dato_Id': '2010-02-28',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 2010,
#   'iso_uke': 8,
#   'fyllingsgrad': 0.25845784,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 2.3578308,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.2857453,
#   'endring_fyllingsgrad': -0.027287453},
#  {'dato_Id': '2004-05-23',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 2004,
#   'iso_uke': 21,
#   'fyllingsgrad': 0.49178347,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 4.486388,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.45267463,
#   'endring_fyllingsgrad': 0.039108843},
#  {'dato_Id': '2008-07-06',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 2008,
#   'iso_uke': 27,
#   'fyllingsgrad': 0.82024777,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 7.482867,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.77181983,
#   'endring_fyllingsgrad': 0.04842794},
#  {'dato_Id': '2001-08-26',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 2001,
#   'iso_uke': 34,
#   'fyllingsgrad': 0.7856688,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 7.167413,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.7797594,
#   'endring_fyllingsgrad': 0.0059093833},
#  {'dato_Id': '1997-08-17',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 1997,
#   'iso_uke': 33,
#   'fyllingsgrad': 0.9101249,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 8.302788,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.9176761,
#   'endring_fyllingsgrad': -0.0075511932},
#  {'dato_Id': '1995-04-02',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 1995,
#   'iso_uke': 13,
#   'fyllingsgrad': 0.20630443,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 1.8820515,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.23699167,
#   'endring_fyllingsgrad': -0.030687243},
#  {'dato_Id': '2001-03-18',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 2001,
#   'iso_uke': 11,
#   'fyllingsgrad': 0.25878242,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 2.360792,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.28318927,
#   'endring_fyllingsgrad': -0.02440685},
#  {'dato_Id': '2002-11-03',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 2002,
#   'iso_uke': 44,
#   'fyllingsgrad': 0.7522459,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 6.8625064,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.77226627,
#   'endring_fyllingsgrad': -0.020020366},
#  {'dato_Id': '2009-12-27',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 2009,
#   'iso_uke': 52,
#   'fyllingsgrad': 0.56919605,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 5.1925993,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.60370696,
#   'endring_fyllingsgrad': -0.03451091},
#  {'dato_Id': '2011-06-26',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 2011,
#   'iso_uke': 25,
#   'fyllingsgrad': 0.7521847,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 6.861948,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.7223626,
#   'endring_fyllingsgrad': 0.029822111},
#  {'dato_Id': '2004-12-26',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 2004,
#   'iso_uke': 52,
#   'fyllingsgrad': 0.7168918,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 6.5399823,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.74773896,
#   'endring_fyllingsgrad': -0.030847132},
#  {'dato_Id': '2007-10-14',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 2007,
#   'iso_uke': 41,
#   'fyllingsgrad': 0.9397114,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 8.572697,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.9395903,
#   'endring_fyllingsgrad': 0.00012111664},
#  {'dato_Id': '1999-05-23',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 1999,
#   'iso_uke': 20,
#   'fyllingsgrad': 0.32039285,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 2.9228446,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.2587195,
#   'endring_fyllingsgrad': 0.061673343},
#  {'dato_Id': '2003-09-28',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 2003,
#   'iso_uke': 39,
#   'fyllingsgrad': 0.80311245,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 7.326546,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.7675712,
#   'endring_fyllingsgrad': 0.035541236},
#  {'dato_Id': '2013-01-13',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 2013,
#   'iso_uke': 2,
#   'fyllingsgrad': 0.5487953,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 5.0064893,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.58315974,
#   'endring_fyllingsgrad': -0.034364462},
#  {'dato_Id': '2007-08-19',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 2007,
#   'iso_uke': 33,
#   'fyllingsgrad': 0.90827847,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 8.285943,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.9014382,
#   'endring_fyllingsgrad': 0.0068402886},
#  {'dato_Id': '2006-11-12',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 2006,
#   'iso_uke': 45,
#   'fyllingsgrad': 0.6608701,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 6.028913,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.65582937,
#   'endring_fyllingsgrad': 0.005040705},
#  {'dato_Id': '2010-04-04',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 2010,
#   'iso_uke': 13,
#   'fyllingsgrad': 0.17506622,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 1.597075,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.19137686,
#   'endring_fyllingsgrad': -0.016310647},
#  {'dato_Id': '2009-11-22',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 2009,
#   'iso_uke': 47,
#   'fyllingsgrad': 0.7393987,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 6.7453055,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.7547831,
#   'endring_fyllingsgrad': -0.015384376},
#  {'dato_Id': '2007-11-11',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 2007,
#   'iso_uke': 45,
#   'fyllingsgrad': 0.9483272,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 8.651295,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.96281856,
#   'endring_fyllingsgrad': -0.014491379},
#  {'dato_Id': '2008-11-30',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 2008,
#   'iso_uke': 48,
#   'fyllingsgrad': 0.73431945,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 6.6989694,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.75220734,
#   'endring_fyllingsgrad': -0.01788789},
#  {'dato_Id': '2007-04-08',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 2007,
#   'iso_uke': 14,
#   'fyllingsgrad': 0.2557873,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 2.3334684,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.27227396,
#   'endring_fyllingsgrad': -0.016486645},
#  {'dato_Id': '2000-11-26',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 2000,
#   'iso_uke': 47,
#   'fyllingsgrad': 0.7534199,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 6.873216,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.7797145,
#   'endring_fyllingsgrad': -0.026294649},
#  {'dato_Id': '2012-10-28',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 2012,
#   'iso_uke': 43,
#   'fyllingsgrad': 0.8579427,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 7.8267455,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.8741066,
#   'endring_fyllingsgrad': -0.016163886},
#  {'dato_Id': '1995-03-19',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 1995,
#   'iso_uke': 11,
#   'fyllingsgrad': 0.26586175,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 2.4253745,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.29975548,
#   'endring_fyllingsgrad': -0.033893734},
#  {'dato_Id': '2000-09-10',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 2000,
#   'iso_uke': 36,
#   'fyllingsgrad': 0.9437783,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 8.609797,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.9453148,
#   'endring_fyllingsgrad': -0.0015365481},
#  {'dato_Id': '2010-08-08',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 2010,
#   'iso_uke': 31,
#   'fyllingsgrad': 0.739144,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 6.742982,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.7286505,
#   'endring_fyllingsgrad': 0.010493517},
#  {'dato_Id': '1998-02-15',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 1998,
#   'iso_uke': 7,
#   'fyllingsgrad': 0.47981277,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 4.3771834,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.50575316,
#   'endring_fyllingsgrad': -0.025940388},
#  {'dato_Id': '2012-05-27',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 2012,
#   'iso_uke': 21,
#   'fyllingsgrad': 0.39356527,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 3.590374,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.30152577,
#   'endring_fyllingsgrad': 0.092039496},
#  {'dato_Id': '2002-10-13',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 2002,
#   'iso_uke': 41,
#   'fyllingsgrad': 0.83360565,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 7.604726,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.85525167,
#   'endring_fyllingsgrad': -0.021646023},
#  {'dato_Id': '2008-02-24',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 2008,
#   'iso_uke': 8,
#   'fyllingsgrad': 0.50496626,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 4.606651,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.5223458,
#   'endring_fyllingsgrad': -0.017379522},
#  {'dato_Id': '2009-02-22',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 2009,
#   'iso_uke': 8,
#   'fyllingsgrad': 0.3518907,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 3.21019,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.38617063,
#   'endring_fyllingsgrad': -0.034279913},
#  {'dato_Id': '1998-06-21',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 1998,
#   'iso_uke': 25,
#   'fyllingsgrad': 0.6415511,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 5.852672,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.57364494,
#   'endring_fyllingsgrad': 0.06790614},
#  {'dato_Id': '2007-01-28',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 2007,
#   'iso_uke': 4,
#   'fyllingsgrad': 0.56029207,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 5.111371,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.5957057,
#   'endring_fyllingsgrad': -0.035413623},
#  {'dato_Id': '2002-12-29',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 2002,
#   'iso_uke': 52,
#   'fyllingsgrad': 0.5237012,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 4.777564,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.55194676,
#   'endring_fyllingsgrad': -0.028245568},
#  {'dato_Id': '2003-10-19',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 2003,
#   'iso_uke': 42,
#   'fyllingsgrad': 0.7675252,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 7.0018945,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.78692055,
#   'endring_fyllingsgrad': -0.019395351},
#  {'dato_Id': '2004-06-20',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 2004,
#   'iso_uke': 25,
#   'fyllingsgrad': 0.6289893,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 5.738075,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.5788557,
#   'endring_fyllingsgrad': 0.050133586},
#  {'dato_Id': '2000-04-16',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 2000,
#   'iso_uke': 15,
#   'fyllingsgrad': 0.19740868,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 1.8008982,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.2336248,
#   'endring_fyllingsgrad': -0.036216125},
#  {'dato_Id': '2005-06-19',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 2005,
#   'iso_uke': 24,
#   'fyllingsgrad': 0.48735046,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 4.445947,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.36145547,
#   'endring_fyllingsgrad': 0.125895},
#  {'dato_Id': '2010-01-24',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 2010,
#   'iso_uke': 3,
#   'fyllingsgrad': 0.4137055,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 3.7741072,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.4509383,
#   'endring_fyllingsgrad': -0.037232816},
#  {'dato_Id': '2003-03-30',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 2003,
#   'iso_uke': 13,
#   'fyllingsgrad': 0.18886402,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 1.722948,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.20123228,
#   'endring_fyllingsgrad': -0.012368262},
#  {'dato_Id': '2006-03-19',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 2006,
#   'iso_uke': 11,
#   'fyllingsgrad': 0.25076434,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 2.2876456,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.29290676,
#   'endring_fyllingsgrad': -0.04214242},
#  {'dato_Id': '2003-11-30',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 2003,
#   'iso_uke': 48,
#   'fyllingsgrad': 0.6416372,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 5.8534575,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.66945297,
#   'endring_fyllingsgrad': -0.02781576},
#  {'dato_Id': '1995-07-30',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 1995,
#   'iso_uke': 30,
#   'fyllingsgrad': 0.9003668,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 8.213768,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.86990744,
#   'endring_fyllingsgrad': 0.030459344},
#  {'dato_Id': '1998-11-08',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 1998,
#   'iso_uke': 45,
#   'fyllingsgrad': 0.86048406,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 7.84993,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.8831816,
#   'endring_fyllingsgrad': -0.022697508},
#  {'dato_Id': '2006-07-09',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 2006,
#   'iso_uke': 27,
#   'fyllingsgrad': 0.582766,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 5.3163934,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.5512298,
#   'endring_fyllingsgrad': 0.03153622},
#  {'dato_Id': '2013-07-21',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 2013,
#   'iso_uke': 29,
#   'fyllingsgrad': 0.7920726,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 7.225833,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.76116365,
#   'endring_fyllingsgrad': 0.030908942},
#  {'dato_Id': '2012-08-05',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 2012,
#   'iso_uke': 31,
#   'fyllingsgrad': 0.92285395,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 8.418911,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.9179547,
#   'endring_fyllingsgrad': 0.0048992634},
#  {'dato_Id': '1998-11-01',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 1998,
#   'iso_uke': 44,
#   'fyllingsgrad': 0.8831816,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 8.056993,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.8880842,
#   'endring_fyllingsgrad': -0.0049026012},
#  {'dato_Id': '2005-11-06',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 2005,
#   'iso_uke': 44,
#   'fyllingsgrad': 0.8559262,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 7.80835,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.85522026,
#   'endring_fyllingsgrad': 0.0007059574},
#  {'dato_Id': '2005-03-06',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 2005,
#   'iso_uke': 9,
#   'fyllingsgrad': 0.35438272,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 3.2329237,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.39831045,
#   'endring_fyllingsgrad': -0.04392773},
#  {'dato_Id': '2008-03-30',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 2008,
#   'iso_uke': 13,
#   'fyllingsgrad': 0.3449706,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 3.1470602,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.3827301,
#   'endring_fyllingsgrad': -0.037759483},
#  {'dato_Id': '2010-09-12',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 2010,
#   'iso_uke': 36,
#   'fyllingsgrad': 0.7124042,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 6.499043,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.72461003,
#   'endring_fyllingsgrad': -0.012205839},
#  {'dato_Id': '1998-03-15',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 1998,
#   'iso_uke': 11,
#   'fyllingsgrad': 0.429594,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 3.9190533,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.46412584,
#   'endring_fyllingsgrad': -0.03453183},
#  {'dato_Id': '1999-07-18',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 1999,
#   'iso_uke': 28,
#   'fyllingsgrad': 0.79868734,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 7.286177,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.763807,
#   'endring_fyllingsgrad': 0.03488034},
#  {'dato_Id': '1999-12-12',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 1999,
#   'iso_uke': 49,
#   'fyllingsgrad': 0.7953385,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 7.255627,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.8298753,
#   'endring_fyllingsgrad': -0.03453678},
#  {'dato_Id': '2000-11-05',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 2000,
#   'iso_uke': 44,
#   'fyllingsgrad': 0.8302008,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 7.573665,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.85040873,
#   'endring_fyllingsgrad': -0.020207942},
#  {'dato_Id': '2002-08-25',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 2002,
#   'iso_uke': 34,
#   'fyllingsgrad': 0.8448431,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 7.707242,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.85635775,
#   'endring_fyllingsgrad': -0.011514664},
#  {'dato_Id': '2004-07-25',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 2004,
#   'iso_uke': 30,
#   'fyllingsgrad': 0.7778642,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 7.0962143,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.74973494,
#   'endring_fyllingsgrad': 0.02812928},
#  {'dato_Id': '2013-08-04',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 2013,
#   'iso_uke': 31,
#   'fyllingsgrad': 0.8119797,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 7.407439,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.79233277,
#   'endring_fyllingsgrad': 0.019646943},
#  {'dato_Id': '2005-06-26',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 2005,
#   'iso_uke': 25,
#   'fyllingsgrad': 0.611184,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 5.5756426,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.48735046,
#   'endring_fyllingsgrad': 0.12383354},
#  {'dato_Id': '2012-07-01',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 2012,
#   'iso_uke': 26,
#   'fyllingsgrad': 0.73410004,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 6.696967,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.6471649,
#   'endring_fyllingsgrad': 0.08693516},
#  {'dato_Id': '2005-03-20',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 2005,
#   'iso_uke': 11,
#   'fyllingsgrad': 0.27342457,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 2.4943676,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.3116053,
#   'endring_fyllingsgrad': -0.03818074},
#  {'dato_Id': '1998-01-11',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 1998,
#   'iso_uke': 2,
#   'fyllingsgrad': 0.6434413,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 5.869916,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.6764386,
#   'endring_fyllingsgrad': -0.03299731},
#  {'dato_Id': '1996-05-05',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 1996,
#   'iso_uke': 18,
#   'fyllingsgrad': 0.16344093,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 1.491021,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.16907057,
#   'endring_fyllingsgrad': -0.005629644},
#  {'dato_Id': '2011-08-14',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 2011,
#   'iso_uke': 32,
#   'fyllingsgrad': 0.8749273,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 7.981691,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.8660827,
#   'endring_fyllingsgrad': 0.008844554},
#  {'dato_Id': '1996-04-21',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 1996,
#   'iso_uke': 16,
#   'fyllingsgrad': 0.15500304,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 1.4140449,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.16586114,
#   'endring_fyllingsgrad': -0.010858104},
#  {'dato_Id': '2012-12-23',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 2012,
#   'iso_uke': 51,
#   'fyllingsgrad': 0.63243705,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 5.7695274,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.6744086,
#   'endring_fyllingsgrad': -0.041971564},
#  {'dato_Id': '2004-02-01',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 2004,
#   'iso_uke': 5,
#   'fyllingsgrad': 0.4205307,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 3.8363714,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.45703956,
#   'endring_fyllingsgrad': -0.03650886},
#  {'dato_Id': '2006-04-09',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 2006,
#   'iso_uke': 14,
#   'fyllingsgrad': 0.16467229,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 1.5022542,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.18764047,
#   'endring_fyllingsgrad': -0.022968188},
#  {'dato_Id': '1999-11-21',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 1999,
#   'iso_uke': 46,
#   'fyllingsgrad': 0.8536151,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 7.7872663,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.8669791,
#   'endring_fyllingsgrad': -0.013364017},
#  {'dato_Id': '1996-03-17',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 1996,
#   'iso_uke': 11,
#   'fyllingsgrad': 0.2732401,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 2.4926848,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.30900866,
#   'endring_fyllingsgrad': -0.03576857},
#  {'dato_Id': '2004-07-04',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 2004,
#   'iso_uke': 27,
#   'fyllingsgrad': 0.7060086,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 6.440698,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.660837,
#   'endring_fyllingsgrad': 0.04517162},
#  {'dato_Id': '2006-12-24',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 2006,
#   'iso_uke': 51,
#   'fyllingsgrad': 0.64036506,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 5.841852,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.6377009,
#   'endring_fyllingsgrad': 0.0026641488},
#  {'dato_Id': '2008-03-02',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 2008,
#   'iso_uke': 9,
#   'fyllingsgrad': 0.4788961,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 4.3688207,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.50496626,
#   'endring_fyllingsgrad': -0.026070148},
#  {'dato_Id': '2000-10-08',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 2000,
#   'iso_uke': 40,
#   'fyllingsgrad': 0.8887267,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 8.107578,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.9024326,
#   'endring_fyllingsgrad': -0.013705909},
#  {'dato_Id': '2003-12-28',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 2003,
#   'iso_uke': 52,
#   'fyllingsgrad': 0.6052338,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 5.5213604,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.6164283,
#   'endring_fyllingsgrad': -0.011194527},
#  {'dato_Id': '2009-09-13',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 2009,
#   'iso_uke': 37,
#   'fyllingsgrad': 0.8834383,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 8.059334,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.85417813,
#   'endring_fyllingsgrad': 0.029260159},
#  {'dato_Id': '2011-01-02',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 2010,
#   'iso_uke': 52,
#   'fyllingsgrad': 0.42158163,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 3.8459587,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.44550496,
#   'endring_fyllingsgrad': -0.023923337},
#  {'dato_Id': '2006-04-30',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 2006,
#   'iso_uke': 17,
#   'fyllingsgrad': 0.1319872,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 1.2040783,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.12795861,
#   'endring_fyllingsgrad': 0.0040285885},
#  {'dato_Id': '2004-06-13',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 2004,
#   'iso_uke': 24,
#   'fyllingsgrad': 0.5788557,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 5.280721,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.5340635,
#   'endring_fyllingsgrad': 0.044792175},
#  {'dato_Id': '1996-08-11',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 1996,
#   'iso_uke': 32,
#   'fyllingsgrad': 0.72194904,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 6.5861177,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.71717644,
#   'endring_fyllingsgrad': 0.0047726035},
#  {'dato_Id': '1997-03-30',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 1997,
#   'iso_uke': 13,
#   'fyllingsgrad': 0.24075179,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 2.1963038,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.26372978,
#   'endring_fyllingsgrad': -0.022977993},
#  {'dato_Id': '2005-04-03',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 2005,
#   'iso_uke': 13,
#   'fyllingsgrad': 0.2111245,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 1.9260235,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.24213707,
#   'endring_fyllingsgrad': -0.03101258},
#  {'dato_Id': '2007-07-22',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 2007,
#   'iso_uke': 29,
#   'fyllingsgrad': 0.87786144,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 8.008458,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.84879947,
#   'endring_fyllingsgrad': 0.029061973},
#  {'dato_Id': '2009-10-04',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 2009,
#   'iso_uke': 40,
#   'fyllingsgrad': 0.9167621,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 8.363337,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.9176153,
#   'endring_fyllingsgrad': -0.0008531809},
#  {'dato_Id': '2007-09-30',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 2007,
#   'iso_uke': 39,
#   'fyllingsgrad': 0.95253557,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 8.689688,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.9579122,
#   'endring_fyllingsgrad': -0.005376637},
#  {'dato_Id': '2006-10-01',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 2006,
#   'iso_uke': 39,
#   'fyllingsgrad': 0.67373693,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 6.1462936,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.67220783,
#   'endring_fyllingsgrad': 0.0015290976},
#  {'dato_Id': '2011-11-20',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 2011,
#   'iso_uke': 46,
#   'fyllingsgrad': 0.8887714,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 8.107986,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.91019416,
#   'endring_fyllingsgrad': -0.021422744},
#  {'dato_Id': '2005-02-20',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 2005,
#   'iso_uke': 7,
#   'fyllingsgrad': 0.44346556,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 4.045599,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.4889129,
#   'endring_fyllingsgrad': -0.04544735},
#  {'dato_Id': '2001-02-11',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 2001,
#   'iso_uke': 6,
#   'fyllingsgrad': 0.38083684,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 3.4742565,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.41627178,
#   'endring_fyllingsgrad': -0.03543493},
#  {'dato_Id': '2011-04-10',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 2011,
#   'iso_uke': 14,
#   'fyllingsgrad': 0.14085242,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 1.284953,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.13187106,
#   'endring_fyllingsgrad': 0.008981362},
#  {'dato_Id': '2012-11-04',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 2012,
#   'iso_uke': 44,
#   'fyllingsgrad': 0.834902,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 7.6165524,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.8579427,
#   'endring_fyllingsgrad': -0.023040712},
#  {'dato_Id': '1996-10-06',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 1996,
#   'iso_uke': 40,
#   'fyllingsgrad': 0.7054481,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 6.4355845,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.69454885,
#   'endring_fyllingsgrad': 0.010899246},
#  {'dato_Id': '2013-10-20',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 2013,
#   'iso_uke': 42,
#   'fyllingsgrad': 0.75038743,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 6.8455524,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.77269197,
#   'endring_fyllingsgrad': -0.022304535},
#  {'dato_Id': '2009-01-25',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 2009,
#   'iso_uke': 4,
#   'fyllingsgrad': 0.5016002,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 4.5759435,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.5360384,
#   'endring_fyllingsgrad': -0.034438193},
#  {'dato_Id': '1998-03-01',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 1998,
#   'iso_uke': 9,
#   'fyllingsgrad': 0.4948679,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 4.5145264,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.49274316,
#   'endring_fyllingsgrad': 0.0021247268},
#  {'dato_Id': '2001-12-30',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 2001,
#   'iso_uke': 52,
#   'fyllingsgrad': 0.6738688,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 6.147496,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.7070858,
#   'endring_fyllingsgrad': -0.033217013},
#  {'dato_Id': '2011-03-27',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 2011,
#   'iso_uke': 12,
#   'fyllingsgrad': 0.1463976,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 1.33554,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.15426442,
#   'endring_fyllingsgrad': -0.007866815},
#  {'dato_Id': '2006-08-13',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 2006,
#   'iso_uke': 32,
#   'fyllingsgrad': 0.6181029,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 5.6387615,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.62218195,
#   'endring_fyllingsgrad': -0.004079044},
#  {'dato_Id': '2004-11-07',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 2004,
#   'iso_uke': 45,
#   'fyllingsgrad': 0.81744504,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 7.457298,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.8271976,
#   'endring_fyllingsgrad': -0.009752572},
#  {'dato_Id': '2008-10-05',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 2008,
#   'iso_uke': 40,
#   'fyllingsgrad': 0.7781057,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 7.098417,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.785652,
#   'endring_fyllingsgrad': -0.0075463057},
#  {'dato_Id': '2005-05-01',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 2005,
#   'iso_uke': 17,
#   'fyllingsgrad': 0.1482097,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 1.3520713,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.1539003,
#   'endring_fyllingsgrad': -0.0056905895},
#  {'dato_Id': '2011-02-27',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 2011,
#   'iso_uke': 8,
#   'fyllingsgrad': 0.22028525,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 2.0095942,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.25360778,
#   'endring_fyllingsgrad': -0.033322528},
#  {'dato_Id': '2010-05-02',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 2010,
#   'iso_uke': 17,
#   'fyllingsgrad': 0.13989237,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 1.2761948,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.12835814,
#   'endring_fyllingsgrad': 0.011534229},
#  {'dato_Id': '1997-09-07',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 1997,
#   'iso_uke': 36,
#   'fyllingsgrad': 0.9137107,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 8.3355,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.907768,
#   'endring_fyllingsgrad': 0.0059427023},
#  {'dato_Id': '2007-12-23',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 2007,
#   'iso_uke': 51,
#   'fyllingsgrad': 0.7786981,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 7.1038218,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.81425667,
#   'endring_fyllingsgrad': -0.03555858},
#  {'dato_Id': '1999-01-24',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 1999,
#   'iso_uke': 3,
#   'fyllingsgrad': 0.5401062,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 4.927222,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.57164747,
#   'endring_fyllingsgrad': -0.031541288},
#  {'dato_Id': '2012-09-30',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 2012,
#   'iso_uke': 39,
#   'fyllingsgrad': 0.91720647,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 8.367391,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.94240534,
#   'endring_fyllingsgrad': -0.025198877},
#  {'dato_Id': '2000-07-09',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 2000,
#   'iso_uke': 27,
#   'fyllingsgrad': 0.85326827,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 7.784102,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.80651057,
#   'endring_fyllingsgrad': 0.046757698},
#  {'dato_Id': '2007-09-09',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 2007,
#   'iso_uke': 36,
#   'fyllingsgrad': 0.94405866,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 8.612354,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.9090761,
#   'endring_fyllingsgrad': 0.034982562},
#  {'dato_Id': '2000-05-07',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 2000,
#   'iso_uke': 18,
#   'fyllingsgrad': 0.2868558,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 2.6168964,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.20689727,
#   'endring_fyllingsgrad': 0.07995851},
#  {'dato_Id': '2008-12-14',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 2008,
#   'iso_uke': 50,
#   'fyllingsgrad': 0.66332865,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 6.051342,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.7015602,
#   'endring_fyllingsgrad': -0.03823155},
#  {'dato_Id': '2011-12-25',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 2011,
#   'iso_uke': 51,
#   'fyllingsgrad': 0.77266026,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 7.0487404,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.80042666,
#   'endring_fyllingsgrad': -0.027766407},
#  {'dato_Id': '1995-02-26',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 1995,
#   'iso_uke': 8,
#   'fyllingsgrad': 0.36997148,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 3.3751352,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.40609422,
#   'endring_fyllingsgrad': -0.03612274},
#  {'dato_Id': '2004-02-29',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 2004,
#   'iso_uke': 9,
#   'fyllingsgrad': 0.31579977,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 2.8809435,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.34776583,
#   'endring_fyllingsgrad': -0.03196606},
#  {'dato_Id': '2004-07-18',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 2004,
#   'iso_uke': 29,
#   'fyllingsgrad': 0.74973494,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 6.8395996,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.7312119,
#   'endring_fyllingsgrad': 0.018523037},
#  {'dato_Id': '2000-10-15',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 2000,
#   'iso_uke': 41,
#   'fyllingsgrad': 0.8713147,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 7.9487343,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.8887267,
#   'endring_fyllingsgrad': -0.017412007},
#  {'dato_Id': '1998-12-13',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 1998,
#   'iso_uke': 50,
#   'fyllingsgrad': 0.7217735,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 6.584516,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.7590578,
#   'endring_fyllingsgrad': -0.037284315},
#  {'dato_Id': '2008-03-23',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 2008,
#   'iso_uke': 12,
#   'fyllingsgrad': 0.3827301,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 3.491528,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.41652378,
#   'endring_fyllingsgrad': -0.033793688},
#  {'dato_Id': '1995-12-03',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 1995,
#   'iso_uke': 48,
#   'fyllingsgrad': 0.8514246,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 7.7672825,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.87889636,
#   'endring_fyllingsgrad': -0.02747178},
#  {'dato_Id': '2008-12-07',
#   'omrType': 'EL',
#   'omrnr': 3,
#   'iso_aar': 2008,
#   'iso_uke': 49,
#   'fyllingsgrad': 0.7015602,
#   'kapasitet_TWh': 9.12269,
#   'fylling_TWh': 6.400117,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.73431945,
# ...
#   'iso_aar': 2000,
#   'iso_uke': 24,
#   'fyllingsgrad': 0.73182845,
#   'kapasitet_TWh': 6.00351,
#   'fylling_TWh': 4.393539,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.7027469,
#   'endring_fyllingsgrad': 0.029081523},
#  {'dato_Id': '2018-08-05',
#   'omrType': 'EL',
#   'omrnr': 1,
#   'iso_aar': 2018,
#   'iso_uke': 31,
#   'fyllingsgrad': 0.72741926,
#   'kapasitet_TWh': 6.00351,
#   'fylling_TWh': 4.367069,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.72483236,
#   'endring_fyllingsgrad': 0.0025869012},
#  {'dato_Id': '2018-09-16',
#   'omrType': 'EL',
#   'omrnr': 1,
#   'iso_aar': 2018,
#   'iso_uke': 37,
#   'fyllingsgrad': 0.8334884,
#   'kapasitet_TWh': 6.00351,
#   'fylling_TWh': 5.003856,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.78330475,
#   'endring_fyllingsgrad': 0.050183654},
#  {'dato_Id': '2012-08-05',
#   'omrType': 'EL',
#   'omrnr': 5,
#   'iso_aar': 2012,
#   'iso_uke': 31,
#   'fyllingsgrad': 0.82782495,
#   'kapasitet_TWh': 17.425789,
#   'fylling_TWh': 14.425503,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.8066154,
#   'endring_fyllingsgrad': 0.021209538},
#  {'dato_Id': '2016-11-27',
#   'omrType': 'EL',
#   'omrnr': 1,
#   'iso_aar': 2016,
#   'iso_uke': 47,
#   'fyllingsgrad': 0.7285435,
#   'kapasitet_TWh': 6.00351,
#   'fylling_TWh': 4.3738184,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.7416854,
#   'endring_fyllingsgrad': -0.0131418705},
#  {'dato_Id': '2020-04-19',
#   'omrType': 'EL',
#   'omrnr': 5,
#   'iso_aar': 2020,
#   'iso_uke': 16,
#   'fyllingsgrad': 0.29087004,
#   'kapasitet_TWh': 17.425789,
#   'fylling_TWh': 5.06864,
#   'neste_Publiseringsdato': '2020-04-29T13:00:00',
#   'fyllingsgrad_forrige_uke': 0.31818715,
#   'endring_fyllingsgrad': -0.027317107},
#  {'dato_Id': '2005-12-18',
#   'omrType': 'EL',
#   'omrnr': 4,
#   'iso_aar': 2005,
#   'iso_uke': 50,
#   'fyllingsgrad': 0.8429737,
#   'kapasitet_TWh': 20.868721,
#   'fylling_TWh': 17.591784,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.85924333,
#   'endring_fyllingsgrad': -0.016269624},
#  {'dato_Id': '2017-12-31',
#   'omrType': 'EL',
#   'omrnr': 1,
#   'iso_aar': 2017,
#   'iso_uke': 52,
#   'fyllingsgrad': 0.6368082,
#   'kapasitet_TWh': 6.00351,
#   'fylling_TWh': 3.823084,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.65736055,
#   'endring_fyllingsgrad': -0.020552337},
#  {'dato_Id': '1998-07-19',
#   'omrType': 'EL',
#   'omrnr': 4,
#   'iso_aar': 1998,
#   'iso_uke': 29,
#   'fyllingsgrad': 0.81156456,
#   'kapasitet_TWh': 20.868721,
#   'fylling_TWh': 16.936314,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.76231855,
#   'endring_fyllingsgrad': 0.049246013},
#  {'dato_Id': '2017-04-16',
#   'omrType': 'EL',
#   'omrnr': 5,
#   'iso_aar': 2017,
#   'iso_uke': 15,
#   'fyllingsgrad': 0.20477982,
#   'kapasitet_TWh': 17.425789,
#   'fylling_TWh': 3.56845,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.21693097,
#   'endring_fyllingsgrad': -0.012151152},
#  {'dato_Id': '2007-06-03',
#   'omrType': 'EL',
#   'omrnr': 5,
#   'iso_aar': 2007,
#   'iso_uke': 22,
#   'fyllingsgrad': 0.3799208,
#   'kapasitet_TWh': 17.425789,
#   'fylling_TWh': 6.62042,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.3039961,
#   'endring_fyllingsgrad': 0.075924724},
#  {'dato_Id': '1996-01-21',
#   'omrType': 'EL',
#   'omrnr': 5,
#   'iso_aar': 1996,
#   'iso_uke': 3,
#   'fyllingsgrad': 0.5910619,
#   'kapasitet_TWh': 17.425789,
#   'fylling_TWh': 10.29972,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.627649,
#   'endring_fyllingsgrad': -0.03658712},
#  {'dato_Id': '2014-07-13',
#   'omrType': 'EL',
#   'omrnr': 5,
#   'iso_aar': 2014,
#   'iso_uke': 28,
#   'fyllingsgrad': 0.7400775,
#   'kapasitet_TWh': 17.425789,
#   'fylling_TWh': 12.896435,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.6736794,
#   'endring_fyllingsgrad': 0.066398084},
#  {'dato_Id': '2014-01-26',
#   'omrType': 'EL',
#   'omrnr': 1,
#   'iso_aar': 2014,
#   'iso_uke': 4,
#   'fyllingsgrad': 0.5325539,
#   'kapasitet_TWh': 6.00351,
#   'fylling_TWh': 3.1971927,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.58145225,
#   'endring_fyllingsgrad': -0.04889834},
#  {'dato_Id': '2018-09-16',
#   'omrType': 'EL',
#   'omrnr': 5,
#   'iso_aar': 2018,
#   'iso_uke': 37,
#   'fyllingsgrad': 0.76819015,
#   'kapasitet_TWh': 17.425789,
#   'fylling_TWh': 13.386319,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.71275544,
#   'endring_fyllingsgrad': 0.055434704},
#  {'dato_Id': '2002-04-14',
#   'omrType': 'EL',
#   'omrnr': 5,
#   'iso_aar': 2002,
#   'iso_uke': 15,
#   'fyllingsgrad': 0.25965175,
#   'kapasitet_TWh': 17.425789,
#   'fylling_TWh': 4.5246367,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.28470707,
#   'endring_fyllingsgrad': -0.02505532},
#  {'dato_Id': '2002-06-09',
#   'omrType': 'EL',
#   'omrnr': 5,
#   'iso_aar': 2002,
#   'iso_uke': 23,
#   'fyllingsgrad': 0.5647473,
#   'kapasitet_TWh': 17.425789,
#   'fylling_TWh': 9.841167,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.46914974,
#   'endring_fyllingsgrad': 0.095597535},
#  {'dato_Id': '2011-11-27',
#   'omrType': 'EL',
#   'omrnr': 1,
#   'iso_aar': 2011,
#   'iso_uke': 47,
#   'fyllingsgrad': 0.86018956,
#   'kapasitet_TWh': 6.00351,
#   'fylling_TWh': 5.1641564,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.8801038,
#   'endring_fyllingsgrad': -0.01991427},
#  {'dato_Id': '2001-08-12',
#   'omrType': 'EL',
#   'omrnr': 1,
#   'iso_aar': 2001,
#   'iso_uke': 32,
#   'fyllingsgrad': 0.88419807,
#   'kapasitet_TWh': 6.00351,
#   'fylling_TWh': 5.3082914,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.8766786,
#   'endring_fyllingsgrad': 0.0075194836},
#  {'dato_Id': '2007-02-11',
#   'omrType': 'EL',
#   'omrnr': 1,
#   'iso_aar': 2007,
#   'iso_uke': 6,
#   'fyllingsgrad': 0.50194997,
#   'kapasitet_TWh': 6.00351,
#   'fylling_TWh': 3.0134614,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.5573601,
#   'endring_fyllingsgrad': -0.055410147},
#  {'dato_Id': '2001-12-16',
#   'omrType': 'EL',
#   'omrnr': 5,
#   'iso_aar': 2001,
#   'iso_uke': 50,
#   'fyllingsgrad': 0.7496366,
#   'kapasitet_TWh': 17.425789,
#   'fylling_TWh': 13.063009,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.77717817,
#   'endring_fyllingsgrad': -0.027541578},
#  {'dato_Id': '2005-11-27',
#   'omrType': 'EL',
#   'omrnr': 1,
#   'iso_aar': 2005,
#   'iso_uke': 47,
#   'fyllingsgrad': 0.9096926,
#   'kapasitet_TWh': 6.00351,
#   'fylling_TWh': 5.461348,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.9300082,
#   'endring_fyllingsgrad': -0.020315588},
#  {'dato_Id': '2001-12-09',
#   'omrType': 'EL',
#   'omrnr': 5,
#   'iso_aar': 2001,
#   'iso_uke': 49,
#   'fyllingsgrad': 0.77717817,
#   'kapasitet_TWh': 17.425789,
#   'fylling_TWh': 13.542942,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.7993285,
#   'endring_fyllingsgrad': -0.022150338},
#  {'dato_Id': '2021-10-03',
#   'omrType': 'EL',
#   'omrnr': 1,
#   'iso_aar': 2021,
#   'iso_uke': 39,
#   'fyllingsgrad': 0.76121336,
#   'kapasitet_TWh': 6.00351,
#   'fylling_TWh': 4.5699515,
#   'neste_Publiseringsdato': '2021-10-13T13:00:00',
#   'fyllingsgrad_forrige_uke': 0.7074072,
#   'endring_fyllingsgrad': 0.053806186},
#  {'dato_Id': '2020-01-12',
#   'omrType': 'EL',
#   'omrnr': 5,
#   'iso_aar': 2020,
#   'iso_uke': 2,
#   'fyllingsgrad': 0.6410947,
#   'kapasitet_TWh': 17.425789,
#   'fylling_TWh': 11.171581,
#   'neste_Publiseringsdato': '2020-01-22T13:00:00',
#   'fyllingsgrad_forrige_uke': 0.6476023,
#   'endring_fyllingsgrad': -0.006507635},
#  {'dato_Id': '2001-04-15',
#   'omrType': 'EL',
#   'omrnr': 5,
#   'iso_aar': 2001,
#   'iso_uke': 15,
#   'fyllingsgrad': 0.24398857,
#   'kapasitet_TWh': 17.425789,
#   'fylling_TWh': 4.2516932,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.26513544,
#   'endring_fyllingsgrad': -0.021146864},
#  {'dato_Id': '2008-02-03',
#   'omrType': 'EL',
#   'omrnr': 5,
#   'iso_aar': 2008,
#   'iso_uke': 5,
#   'fyllingsgrad': 0.60736775,
#   'kapasitet_TWh': 17.425789,
#   'fylling_TWh': 10.583862,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.6341359,
#   'endring_fyllingsgrad': -0.026768148},
#  {'dato_Id': '2019-07-21',
#   'omrType': 'EL',
#   'omrnr': 1,
#   'iso_aar': 2019,
#   'iso_uke': 29,
#   'fyllingsgrad': 0.7960092,
#   'kapasitet_TWh': 6.00351,
#   'fylling_TWh': 4.778849,
#   'neste_Publiseringsdato': '2019-07-31T13:00:00',
#   'fyllingsgrad_forrige_uke': 0.7950594,
#   'endring_fyllingsgrad': 0.0009498},
#  {'dato_Id': '1999-02-28',
#   'omrType': 'EL',
#   'omrnr': 1,
#   'iso_aar': 1999,
#   'iso_uke': 8,
#   'fyllingsgrad': 0.3022797,
#   'kapasitet_TWh': 6.00351,
#   'fylling_TWh': 1.8147391,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.340777,
#   'endring_fyllingsgrad': -0.0384973},
#  {'dato_Id': '2002-08-25',
#   'omrType': 'EL',
#   'omrnr': 5,
#   'iso_aar': 2002,
#   'iso_uke': 34,
#   'fyllingsgrad': 0.847132,
#   'kapasitet_TWh': 17.425789,
#   'fylling_TWh': 14.761945,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.8518477,
#   'endring_fyllingsgrad': -0.004715681},
#  {'dato_Id': '1995-07-30',
#   'omrType': 'EL',
#   'omrnr': 5,
#   'iso_aar': 1995,
#   'iso_uke': 30,
#   'fyllingsgrad': 0.8191954,
#   'kapasitet_TWh': 17.425789,
#   'fylling_TWh': 14.2751255,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.7790947,
#   'endring_fyllingsgrad': 0.040100694},
#  {'dato_Id': '2020-06-21',
#   'omrType': 'EL',
#   'omrnr': 5,
#   'iso_aar': 2020,
#   'iso_uke': 25,
#   'fyllingsgrad': 0.5701489,
#   'kapasitet_TWh': 17.425789,
#   'fylling_TWh': 9.935294,
#   'neste_Publiseringsdato': '2020-07-01T13:00:00',
#   'fyllingsgrad_forrige_uke': 0.4204512,
#   'endring_fyllingsgrad': 0.14969769},
#  {'dato_Id': '2007-10-21',
#   'omrType': 'EL',
#   'omrnr': 1,
#   'iso_aar': 2007,
#   'iso_uke': 42,
#   'fyllingsgrad': 0.8845027,
#   'kapasitet_TWh': 6.00351,
#   'fylling_TWh': 5.3101206,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.8959187,
#   'endring_fyllingsgrad': -0.011416018},
#  {'dato_Id': '2022-10-16',
#   'omrType': 'EL',
#   'omrnr': 1,
#   'iso_aar': 2022,
#   'iso_uke': 41,
#   'fyllingsgrad': 0.8097714,
#   'kapasitet_TWh': 6.00351,
#   'fylling_TWh': 4.8614707,
#   'neste_Publiseringsdato': '2022-10-26T13:00:00',
#   'fyllingsgrad_forrige_uke': 0.79345685,
#   'endring_fyllingsgrad': 0.016314566},
#  {'dato_Id': '2008-04-06',
#   'omrType': 'EL',
#   'omrnr': 5,
#   'iso_aar': 2008,
#   'iso_uke': 14,
#   'fyllingsgrad': 0.3291064,
#   'kapasitet_TWh': 17.425789,
#   'fylling_TWh': 5.7349386,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.3590923,
#   'endring_fyllingsgrad': -0.029985905},
#  {'dato_Id': '2022-07-03',
#   'omrType': 'EL',
#   'omrnr': 5,
#   'iso_aar': 2022,
#   'iso_uke': 26,
#   'fyllingsgrad': 0.54299706,
#   'kapasitet_TWh': 17.425789,
#   'fylling_TWh': 9.4621525,
#   'neste_Publiseringsdato': '2022-07-13T13:00:00',
#   'fyllingsgrad_forrige_uke': 0.4670914,
#   'endring_fyllingsgrad': 0.07590565},
#  {'dato_Id': '1997-04-20',
#   'omrType': 'EL',
#   'omrnr': 5,
#   'iso_aar': 1997,
#   'iso_uke': 16,
#   'fyllingsgrad': 0.2455159,
#   'kapasitet_TWh': 17.425789,
#   'fylling_TWh': 4.278308,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.26815107,
#   'endring_fyllingsgrad': -0.022635177},
#  {'dato_Id': '2013-12-22',
#   'omrType': 'EL',
#   'omrnr': 5,
#   'iso_aar': 2013,
#   'iso_uke': 51,
#   'fyllingsgrad': 0.6928958,
#   'kapasitet_TWh': 17.425789,
#   'fylling_TWh': 12.074257,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.7103271,
#   'endring_fyllingsgrad': -0.01743126},
#  {'dato_Id': '2008-09-21',
#   'omrType': 'EL',
#   'omrnr': 5,
#   'iso_aar': 2008,
#   'iso_uke': 38,
#   'fyllingsgrad': 0.8573139,
#   'kapasitet_TWh': 17.425789,
#   'fylling_TWh': 14.939371,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.8707076,
#   'endring_fyllingsgrad': -0.0133937},
#  {'dato_Id': '2013-07-07',
#   'omrType': 'EL',
#   'omrnr': 1,
#   'iso_aar': 2013,
#   'iso_uke': 27,
#   'fyllingsgrad': 0.8864206,
#   'kapasitet_TWh': 6.00351,
#   'fylling_TWh': 5.321635,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.8887351,
#   'endring_fyllingsgrad': -0.002314508},
#  {'dato_Id': '2010-10-24',
#   'omrType': 'EL',
#   'omrnr': 1,
#   'iso_aar': 2010,
#   'iso_uke': 42,
#   'fyllingsgrad': 0.8706948,
#   'kapasitet_TWh': 6.00351,
#   'fylling_TWh': 5.227225,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.903287,
#   'endring_fyllingsgrad': -0.032592177},
#  {'dato_Id': '2019-02-17',
#   'omrType': 'EL',
#   'omrnr': 1,
#   'iso_aar': 2019,
#   'iso_uke': 7,
#   'fyllingsgrad': 0.36318678,
#   'kapasitet_TWh': 6.00351,
#   'fylling_TWh': 2.1803954,
#   'neste_Publiseringsdato': '2019-02-27T13:00:00',
#   'fyllingsgrad_forrige_uke': 0.41185972,
#   'endring_fyllingsgrad': -0.048672944},
#  {'dato_Id': '2012-01-08',
#   'omrType': 'EL',
#   'omrnr': 5,
#   'iso_aar': 2012,
#   'iso_uke': 1,
#   'fyllingsgrad': 0.7624815,
#   'kapasitet_TWh': 17.425789,
#   'fylling_TWh': 13.286841,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.7922118,
#   'endring_fyllingsgrad': -0.02973026},
#  {'dato_Id': '2008-11-16',
#   'omrType': 'EL',
#   'omrnr': 1,
#   'iso_aar': 2008,
#   'iso_uke': 46,
#   'fyllingsgrad': 0.83437973,
#   'kapasitet_TWh': 6.00351,
#   'fylling_TWh': 5.0092072,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.8418592,
#   'endring_fyllingsgrad': -0.007479489},
#  {'dato_Id': '2023-07-30',
#   'omrType': 'EL',
#   'omrnr': 5,
#   'iso_aar': 2023,
#   'iso_uke': 30,
#   'fyllingsgrad': 0.7741014,
#   'kapasitet_TWh': 17.425789,
#   'fylling_TWh': 13.489327,
#   'neste_Publiseringsdato': '2023-08-09T13:00:00',
#   'fyllingsgrad_forrige_uke': 0.759367,
#   'endring_fyllingsgrad': 0.014734387},
#  {'dato_Id': '2017-12-10',
#   'omrType': 'EL',
#   'omrnr': 5,
#   'iso_aar': 2017,
#   'iso_uke': 49,
#   'fyllingsgrad': 0.7808395,
#   'kapasitet_TWh': 17.425789,
#   'fylling_TWh': 13.606744,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.78909546,
#   'endring_fyllingsgrad': -0.008255959},
#  {'dato_Id': '2002-08-04',
#   'omrType': 'EL',
#   'omrnr': 5,
#   'iso_aar': 2002,
#   'iso_uke': 31,
#   'fyllingsgrad': 0.85658973,
#   'kapasitet_TWh': 17.425789,
#   'fylling_TWh': 14.926752,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.8471467,
#   'endring_fyllingsgrad': 0.009443045},
#  {'dato_Id': '2022-08-07',
#   'omrType': 'EL',
#   'omrnr': 5,
#   'iso_aar': 2022,
#   'iso_uke': 31,
#   'fyllingsgrad': 0.69270784,
#   'kapasitet_TWh': 17.425789,
#   'fylling_TWh': 12.07098,
#   'neste_Publiseringsdato': '2022-08-17T13:00:00',
#   'fyllingsgrad_forrige_uke': 0.66345346,
#   'endring_fyllingsgrad': 0.029254377},
#  {'dato_Id': '2007-05-27',
#   'omrType': 'EL',
#   'omrnr': 1,
#   'iso_aar': 2007,
#   'iso_uke': 21,
#   'fyllingsgrad': 0.4518291,
#   'kapasitet_TWh': 6.00351,
#   'fylling_TWh': 2.7125607,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.4046975,
#   'endring_fyllingsgrad': 0.047131598},
#  {'dato_Id': '2004-01-25',
#   'omrType': 'EL',
#   'omrnr': 5,
#   'iso_aar': 2004,
#   'iso_uke': 4,
#   'fyllingsgrad': 0.45448038,
#   'kapasitet_TWh': 17.425789,
#   'fylling_TWh': 7.919679,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.48955685,
#   'endring_fyllingsgrad': -0.03507647},
#  {'dato_Id': '2010-03-14',
#   'omrType': 'EL',
#   'omrnr': 1,
#   'iso_aar': 2010,
#   'iso_uke': 10,
#   'fyllingsgrad': 0.16523993,
#   'kapasitet_TWh': 6.00351,
#   'fylling_TWh': 0.99201953,
#   'neste_Publiseringsdato': '0001-01-01T00:00:00',
#   'fyllingsgrad_forrige_uke': 0.19566645,
#   'endring_fyllingsgrad': -0.030426517},
#  ...]
